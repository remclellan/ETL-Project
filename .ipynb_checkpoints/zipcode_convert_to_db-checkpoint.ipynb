# %% [markdown]
# # County Source Data
#
# Using Pandas to import csv file of Zipcodes to identify counties associated with cities in the Instacart dataset.
#
# The reason for this is that the Food Desert data is based on county level information and the only way to compare the areas is to utilize the data set and join in MongoDB.

# %% [markdown]
# ### Import dependencies

# %%
import os
import pandas as pd
from pandas import DataFrame
import pymongo

# %% [markdown]
# ### Setup DB connection and establish collection for storage

# %%
# Setup connection to MongoDB
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Create Collection to receive data (first drop and then )
db = client.food_desert_db
collection = db.zipcode_county_data
collection.drop()

# %%
collection = db.zipcode_county_data

# %% [markdown]
# ### Import and read file
#
# Bringing in path for datafile as well as reference file of states for Instacart Service area

# %%
csv_path = os.path.join('Data', 'zip_code_database.csv')
states_path = os.path.join('Data','instacart_states.csv')

# %%
states = pd.read_csv(states_path)
states.head()
# Out:
#    Unnamed: 0 state  counts
# 0           0    NY     851
# 1           1    PA     850
# 2           2    CA     704
# 3           3    TX     524
# 4           4    OH     513

# %%
pd.read_csv(csv_path, nrows=1).columns
# Out:
# Index(['zip', 'type', 'decommissioned', 'primary_city', 'acceptable_cities',
#        'unacceptable_cities', 'state', 'county', 'timezone', 'area_codes',
#        'world_region', 'country', 'latitude', 'longitude',
#        'irs_estimated_population_2015'],
#       dtype='object')

# %%
data = pd.read_csv(csv_path)[['primary_city', 'acceptable_cities','state', 'county']]
data.head(10)
# Out:
#   primary_city acceptable_cities state               county
# 0   Holtsville               NaN    NY              Suffolk
# 1   Holtsville               NaN    NY              Suffolk
# 2     Adjuntas               NaN    PR   Adjuntas Municipio
# 3       Aguada               NaN    PR     Aguada Municipio
# 4    Aguadilla             Ramey    PR  Aguadilla Municipio
# 5    Aguadilla             Ramey    PR                  NaN
# 6    Aguadilla               NaN    PR                  NaN
# 7      Maricao               NaN    PR    Maricao Municipio
# 8       Anasco               NaN    PR     Anasco Municipio
# 9      Angeles               NaN    PR                  NaN

# %%
data.count()
# Out:
# primary_city         42632
# acceptable_cities     9023
# state                42632
# county               41790
# dtype: int64

# %%
data.loc[data.isnull().any(axis=1)]
# Out:
#         primary_city acceptable_cities state  \
# 0         Holtsville               NaN    NY
# 1         Holtsville               NaN    NY
# 2           Adjuntas               NaN    PR
# 3             Aguada               NaN    PR
# 5          Aguadilla             Ramey    PR
# 6          Aguadilla               NaN    PR
# 7            Maricao               NaN    PR
# 8             Anasco               NaN    PR
# 9            Angeles               NaN    PR
# 10           Arecibo               NaN    PR
# 11           Arecibo               NaN    PR
# 12           Arecibo               NaN    PR
# 13          Bajadero               NaN    PR
# 14       Barceloneta               NaN    PR
# 15          Boqueron               NaN    PR
# 16         Cabo Rojo               NaN    PR
# 17          Penuelas               NaN    PR
# 18             Camuy               NaN    PR
# 20           Rosario               NaN    PR
# 21     Sabana Grande               NaN    PR
# 22            Ciales               NaN    PR
# 23            Utuado               NaN    PR
# 24            Dorado               NaN    PR
# 25          Ensenada               NaN    PR
# 26           Florida               NaN    PR
# 27       Garrochales               NaN    PR
# 28           Guanica               NaN    PR
# 29        Guayanilla               NaN    PR
# 30           Hatillo               NaN    PR
# 31       Hormigueros               NaN    PR
# ...              ...               ...   ...
# 42586         Teller               NaN    AK
# 42587            Tok               NaN    AK
# 42589        Venetie               NaN    AK
# 42590     Wainwright               NaN    AK
# 42591          Wales               NaN    AK
# 42594         Ambler               NaN    AK
# 42597      Fairbanks               NaN    AK
# 42599         Juneau               NaN    AK
# 42600         Juneau               NaN    AK
# 42601         Juneau               NaN    AK
# 42602         Juneau               NaN    AK
# 42603         Juneau               NaN    AK
# 42604         Angoon               NaN    AK
# 42607     Elfin Cove               NaN    AK
# 42608       Gustavus               NaN    AK
# 42609         Haines               NaN    AK
# 42610         Hoonah               NaN    AK
# 42611           Kake               NaN    AK
# 42612        Pelican               NaN    AK
# 42614          Sitka               NaN    AK
# 42616        Skagway               NaN    AK
# 42618         Juneau               NaN    AK
# 42623          Craig               NaN    AK
# 42624       Hydaburg               NaN    AK
# 42625          Hyder               NaN    AK
# 42626        Klawock               NaN    AK
# 42627     Metlakatla               NaN    AK
# 42628    Point Baker               NaN    AK
# 42629      Ward Cove               NaN    AK
# 42630       Wrangell               NaN    AK
#
#                                   county
# 0                                Suffolk
# 1                                Suffolk
# 2                     Adjuntas Municipio
# 3                       Aguada Municipio
# 5                                    NaN
# 6                                    NaN
# 7                      Maricao Municipio
# 8                       Anasco Municipio
# 9                                    NaN
# 10                     Arecibo Municipio
# 11                                   NaN
# 12                                   NaN
# 13                     Arecibo Municipio
# 14                 Barceloneta Municipio
# 15                   Cabo Rojo Municipio
# 16                   Cabo Rojo Municipio
# 17                    Penuelas Municipio
# 18                       Camuy Municipio
# 20                                   NaN
# 21               Sabana Grande Municipio
# 22                      Ciales Municipio
# 23                      Utuado Municipio
# 24                      Dorado Municipio
# 25                     Guanica Municipio
# 26                     Florida Municipio
# 27                     Arecibo Municipio
# 28                     Guanica Municipio
# 29                  Guayanilla Municipio
# 30                     Hatillo Municipio
# 31                 Hormigueros Municipio
# ...                                  ...
# 42586                   Nome Census Area
# 42587    Southeast Fairbanks Census Area
# 42589          Yukon-Koyukuk Census Area
# 42590                        North Slope
# 42591                   Nome Census Area
# 42594                   Northwest Arctic
# 42597          Yukon-Koyukuk Census Area
# 42599                    Juneau City and
# 42600                 City and of Juneau
# 42601                 City and of Juneau
# 42602                 City and of Juneau
# 42603                 City and of Juneau
# 42604          Hoonah-Angoon Census Area
# 42607          Hoonah-Angoon Census Area
# 42608          Hoonah-Angoon Census Area
# 42609                             Haines
# 42610          Hoonah-Angoon Census Area
# 42611             Petersburg Census Area
# 42612          Hoonah-Angoon Census Area
# 42614                     Sitka City and
# 42616               Skagway Municipality
# 42618                 City and of Juneau
# 42623  Prince of Wales-Hyder Census Area
# 42624  Prince of Wales-Hyder Census Area
# 42625  Prince of Wales-Hyder Census Area
# 42626  Prince of Wales-Hyder Census Area
# 42627    Prince of Wales-Outer Ketchikan
# 42628  Prince of Wales-Hyder Census Area
# 42629                  Ketchikan Gateway
# 42630                  Wrangell City and
#
# [33655 rows x 4 columns]

# %%
data.dropna(subset=['county'], inplace=True)

# %%
#data.drop(data.loc[data['state']=="PR"].index, inplace=True)
data = data[data['state'].isin(states['state'])]

# %%
data['acceptable_cities'].fillna(data['primary_city'],inplace=True)
data.head()
# Out:
#     primary_city acceptable_cities state     county
# 0     Holtsville        Holtsville    NY    Suffolk
# 1     Holtsville        Holtsville    NY    Suffolk
# 194       Agawam            Agawam    MA    Hampden
# 195      Amherst   Cushman, Pelham    MA  Hampshire
# 196      Amherst           Amherst    MA  Hampshire

# %%
data_duplicates_removed = DataFrame.drop_duplicates(data).copy()
data_duplicates_removed.count()
# Out:
# primary_city         31912
# acceptable_cities    31912
# state                31912
# county               31912
# dtype: int64

# %%
data_duplicates_removed.head()
# Out:
#     primary_city acceptable_cities state     county
# 0     Holtsville        Holtsville    NY    Suffolk
# 194       Agawam            Agawam    MA    Hampden
# 195      Amherst   Cushman, Pelham    MA  Hampshire
# 196      Amherst           Amherst    MA  Hampshire
# 198        Barre             Barre    MA  Worcester

# %% [markdown]
# ### Add column to insert city, state so that it can be used to match up with the instacart data and drop unnecessary columns

# %%
data_duplicates_removed['primary_city-state'] = data_duplicates_removed['primary_city'] +', '+ data_duplicates_removed['state']
data_duplicates_removed['acceptable_city-state'] = data_duplicates_removed['acceptable_cities'] +', '+ data_duplicates_removed['state']
data_duplicates_removed['primary_city-state/county'] = data_duplicates_removed['primary_city'] +', '+ data_duplicates_removed['state'] +'/'+ data_duplicates_removed['county']
data_duplicates_removed['acceptable_city-state/county'] = data_duplicates_removed['acceptable_cities'] +', '+ data_duplicates_removed['state'] +'/'+ data_duplicates_removed['county']
data_duplicates_removed.head(10)
# Out:
#     primary_city acceptable_cities state     county primary_city-state  \
# 0     Holtsville        Holtsville    NY    Suffolk     Holtsville, NY
# 194       Agawam            Agawam    MA    Hampden         Agawam, MA
# 195      Amherst   Cushman, Pelham    MA  Hampshire        Amherst, MA
# 196      Amherst           Amherst    MA  Hampshire        Amherst, MA
# 198        Barre             Barre    MA  Worcester          Barre, MA
# 199  Belchertown       Belchertown    MA  Hampshire    Belchertown, MA
# 200    Blandford         Blandford    MA    Hampden      Blandford, MA
# 201   Bondsville        Bondsville    MA    Hampden     Bondsville, MA
# 202    Brimfield         Brimfield    MA    Hampden      Brimfield, MA
# 203      Chester           Chester    MA    Hampden        Chester, MA
#
#     acceptable_city-state  primary_city-state/county  \
# 0          Holtsville, NY     Holtsville, NY/Suffolk
# 194            Agawam, MA         Agawam, MA/Hampden
# 195   Cushman, Pelham, MA      Amherst, MA/Hampshire
# 196           Amherst, MA      Amherst, MA/Hampshire
# 198             Barre, MA        Barre, MA/Worcester
# 199       Belchertown, MA  Belchertown, MA/Hampshire
# 200         Blandford, MA      Blandford, MA/Hampden
# 201        Bondsville, MA     Bondsville, MA/Hampden
# 202         Brimfield, MA      Brimfield, MA/Hampden
# 203           Chester, MA        Chester, MA/Hampden
#
#       acceptable_city-state/county
# 0           Holtsville, NY/Suffolk
# 194             Agawam, MA/Hampden
# 195  Cushman, Pelham, MA/Hampshire
# 196          Amherst, MA/Hampshire
# 198            Barre, MA/Worcester
# 199      Belchertown, MA/Hampshire
# 200          Blandford, MA/Hampden
# 201         Bondsville, MA/Hampden
# 202          Brimfield, MA/Hampden
# 203            Chester, MA/Hampden

# %%
data_duplicates_removed['primary_city-state/county'].value_counts()
# Out:
# Pittsburgh, PA/Allegheny          41
# Miami, FL/Miami-Dade              35
# Cincinnati, OH/Hamilton           32
# Los Angeles, CA/Los Angeles       29
# Louisville, KY/Jefferson          26
# Fort Lauderdale, FL/Broward       22
# Saint Louis, MO/St. Louis         21
# Minneapolis, MN/Hennepin          20
# Cleveland, OH/Cuyahoga            20
# Indianapolis, IN/Marion           19
# Salt Lake City, UT/Salt Lake      18
# Birmingham, AL/Jefferson          17
# San Antonio, TX/Bexar             17
# New York, NY/New York             16
# Fort Worth, TX/Tarrant            15
# Orlando, FL/Orange                15
# Tampa, FL/Hillsborough            15
# Buffalo, NY/Erie                  15
# Dayton, OH/Montgomery             14
# Milwaukee, WI/Milwaukee           14
# Atlanta, GA/Fulton                13
# Saint Petersburg, FL/Pinellas     13
# Seattle, WA/King                  13
# Baltimore, MD/Baltimore city      12
# West Palm Beach, FL/Palm Beach    11
# Saint Paul, MN/Ramsey             11
# Columbus, OH/Franklin             10
# Oklahoma City, OK/Oklahoma        10
# Pompano Beach, FL/Broward         10
# Nashville, TN/Davidson             9
#                                   ..
# Blacksburg, SC/Cherokee            1
# Sharon, KS/Barber                  1
# Middleburgh, NY/Schoharie          1
# Deer Park, NY/Suffolk              1
# Max, NE/Dundy                      1
# Norlina, NC/Warren                 1
# Costa Mesa, CA/Orange              1
# Hitterdal, MN/Clay                 1
# Palmyra, ME/Somerset               1
# Bingen, WA/Klickitat               1
# Conneaut Lake, PA/Crawford         1
# Rouses Point, NY/Clinton           1
# Ellsworth, MN/Nobles               1
# Manilla, IN/Rush                   1
# Scottsmoor, FL/Brevard             1
# Neck City, MO/Jasper               1
# Los Osos, CA/San Luis Obispo       1
# Wales, ND/Cavalier                 1
# New Providence, PA/Lancaster       1
# Newhall, IA/Benton                 1
# Willow Springs, MO/Howell          1
# Sicklerville, NJ/Camden            1
# Fairchild, WI/Eau Claire           1
# Buckeye, IA/Hardin                 1
# Wadena, MN/Wadena                  1
# Streator, IL/LaSalle               1
# Mannboro, VA/Amelia                1
# Fountaintown, IN/Shelby            1
# Rockbridge, OH/Hocking             1
# Carthage, IL/Hancock               1
# Name: primary_city-state/county, Length: 29866, dtype: int64

# %%
data_duplicates_removed['acceptable_city-state/county'].value_counts()
# Out:
# Flushing, NY/Queens                                                                                                12
# Baltimore, MD/Baltimore                                                                                            11
# Boston, MA/Suffolk                                                                                                 11
# Cleveland, OH/Cuyahoga                                                                                             10
# Jamaica, NY/Queens                                                                                                 10
# Detroit, MI/Wayne                                                                                                   7
# Richmond, RI/Washington                                                                                             6
# Gallup, NM/McKinley                                                                                                 6
# Fairbanks, AK/Fairbanks North Star                                                                                  5
# West Deptford, NJ/Gloucester                                                                                        5
# Kingman, AZ/Mohave                                                                                                  5
# Chinle, AZ/Apache                                                                                                   5
# Flagstaff, AZ/Coconino                                                                                              5
# Red Bank, NJ/Monmouth                                                                                               4
# Los Angeles, CA/Los Angeles                                                                                         4
# Shawnee Mission, Shawnee Msn, KS/Johnson                                                                            4
# Des Moines, IA/Polk                                                                                                 4
# Bethel, AK/Bethel Census Area                                                                                       4
# Miami, FL/Miami-Dade                                                                                                4
# Van Nuys, CA/Los Angeles                                                                                            4
# Santa Clarita, CA/Los Angeles                                                                                       4
# Silver City, NM/Grant                                                                                               4
# New Haven, CT/New Haven                                                                                             4
# Severance, CO/Weld                                                                                                  4
# Hartford, CT/Hartford                                                                                               4
# Norristown, PA/Montgomery                                                                                           4
# Barrow, AK/North Slope                                                                                              4
# Las Vegas, NV/Clark                                                                                                 4
# Scranton, PA/Lackawanna                                                                                             4
# Oakland, FL/Orange                                                                                                  3
#                                                                                                                    ..
# Ozone, AR/Johnson                                                                                                   1
# Palmerdale, AL/Jefferson                                                                                            1
# N Palm Spgs, N Palm Springs, No Palm Springs, CA/Riverside                                                          1
# Fr Settlement, LA/Livingston                                                                                        1
# Buckingham, IL/Kankakee                                                                                             1
# Garfield, WA/Whitman                                                                                                1
# Yale, IL/Jasper                                                                                                     1
# Belleville, KS/Republic                                                                                             1
# Lk Peekskill, NY/Putnam                                                                                             1
# E Carondelet, IL/St. Clair                                                                                          1
# Stevens, PA/Lancaster                                                                                               1
# Waverly, SD/Codington                                                                                               1
# Monroe, MI/Monroe                                                                                                   1
# New Tripoli, PA/Lehigh                                                                                              1
# Macomb, MI/Macomb                                                                                                   1
# Biscoe, NC/Montgomery                                                                                               1
# Arrowhead Farms, Arrowhed Farm, Devore Heights, Devore Hghts, Muscoy, Sn Bernrdno, Verdemont, CA/San Bernardino     1
# Youngstown, FL/Bay                                                                                                  1
# Ostrander, MN/Fillmore                                                                                              1
# Vandemere, NC/Pamlico                                                                                               1
# Templeville, MD/Caroline                                                                                            1
# Elliott, IA/Montgomery                                                                                              1
# Guide Rock, NE/Webster                                                                                              1
# Earlimart, CA/Tulare                                                                                                1
# Hebbronville, TX/Jim Hogg                                                                                           1
# Rice, VA/Prince Edward                                                                                              1
# Cochranton, PA/Crawford                                                                                             1
# Townsend, VA/Northampton                                                                                            1
# Rochester, NY/Monroe                                                                                                1
# Carthage, IL/Hancock                                                                                                1
# Name: acceptable_city-state/county, Length: 31128, dtype: int64

# %%
primary_cities = data_duplicates_removed[['primary_city-state/county']]
primary_cities.rename(columns = {'primary_city-state/county': 'city-state/county'}, inplace = True) 
primary_cities.head()
# Out:
# C:\Users\steph\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#           city-state/county
# 0    Holtsville, NY/Suffolk
# 194      Agawam, MA/Hampden
# 195   Amherst, MA/Hampshire
# 196   Amherst, MA/Hampshire
# 198     Barre, MA/Worcester

# %%
acceptable_cities = data_duplicates_removed[['acceptable_city-state/county']]
acceptable_cities.rename(columns = {'acceptable_city-state/county': 'city-state/county'}, inplace = True) 
acceptable_cities.head()
# Out:
#                  city-state/county
# 0           Holtsville, NY/Suffolk
# 194             Agawam, MA/Hampden
# 195  Cushman, Pelham, MA/Hampshire
# 196          Amherst, MA/Hampshire
# 198            Barre, MA/Worcester

# %%
all_cities = pd.merge(primary_cities, acceptable_cities, on='city-state/county', how='outer')
all_cities.head()
# Out:
#         city-state/county
# 0  Holtsville, NY/Suffolk
# 1      Agawam, MA/Hampden
# 2   Amherst, MA/Hampshire
# 3   Amherst, MA/Hampshire
# 4   Amherst, MA/Hampshire

# %%
all_cities.count()
# Out:
# city-state/county    40503
# dtype: int64

# %%
all_cities[['city-state','county']] = all_cities['city-state/county'].str.split('/', n=1, expand=True)
all_cities.head()
# Out:
#         city-state/county      city-state     county
# 0  Holtsville, NY/Suffolk  Holtsville, NY    Suffolk
# 1      Agawam, MA/Hampden      Agawam, MA    Hampden
# 2   Amherst, MA/Hampshire     Amherst, MA  Hampshire
# 3   Amherst, MA/Hampshire     Amherst, MA  Hampshire
# 4   Amherst, MA/Hampshire     Amherst, MA  Hampshire

# %%
collection.insert_many(all_cities.to_dict('records'))

# %%
listings = db.zipcode_county_data.find()

for listing in listings:
    print(listing)
# Out:
# {'_id': ObjectId('5e1aa8bd051df6979a54fbd4'), 'city-state/county': 'Holtsville, NY/Suffolk', 'city-state': 'Holtsville, NY', 'county': 'Suffolk'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbd5'), 'city-state/county': 'Agawam, MA/Hampden', 'city-state': 'Agawam, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbd6'), 'city-state/county': 'Amherst, MA/Hampshire', 'city-state': 'Amherst, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbd7'), 'city-state/county': 'Amherst, MA/Hampshire', 'city-state': 'Amherst, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbd8'), 'city-state/county': 'Amherst, MA/Hampshire', 'city-state': 'Amherst, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbd9'), 'city-state/county': 'Amherst, MA/Hampshire', 'city-state': 'Amherst, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbda'), 'city-state/county': 'Barre, MA/Worcester', 'city-state': 'Barre, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbdb'), 'city-state/county': 'Belchertown, MA/Hampshire', 'city-state': 'Belchertown, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbdc'), 'city-state/county': 'Blandford, MA/Hampden', 'city-state': 'Blandford, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbdd'), 'city-state/county': 'Bondsville, MA/Hampden', 'city-state': 'Bondsville, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbde'), 'city-state/county': 'Brimfield, MA/Hampden', 'city-state': 'Brimfield, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbdf'), 'city-state/county': 'Chester, MA/Hampden', 'city-state': 'Chester, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbe0'), 'city-state/county': 'Chesterfield, MA/Hampshire', 'city-state': 'Chesterfield, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbe1'), 'city-state/county': 'Chicopee, MA/Hampden', 'city-state': 'Chicopee, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbe2'), 'city-state/county': 'Chicopee, MA/Hampden', 'city-state': 'Chicopee, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbe3'), 'city-state/county': 'Chicopee, MA/Hampden', 'city-state': 'Chicopee, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbe4'), 'city-state/county': 'Cummington, MA/Hampshire', 'city-state': 'Cummington, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbe5'), 'city-state/county': 'Easthampton, MA/Hampshire', 'city-state': 'Easthampton, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbe6'), 'city-state/county': 'East Longmeadow, MA/Hampden', 'city-state': 'East Longmeadow, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbe7'), 'city-state/county': 'East Otis, MA/Berkshire', 'city-state': 'East Otis, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbe8'), 'city-state/county': 'Feeding Hills, MA/Hampden', 'city-state': 'Feeding Hills, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbe9'), 'city-state/county': 'Gilbertville, MA/Worcester', 'city-state': 'Gilbertville, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbea'), 'city-state/county': 'Goshen, MA/Hampshire', 'city-state': 'Goshen, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbeb'), 'city-state/county': 'Granby, MA/Hampshire', 'city-state': 'Granby, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbec'), 'city-state/county': 'Granville, MA/Hampden', 'city-state': 'Granville, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbed'), 'city-state/county': 'Hadley, MA/Hampshire', 'city-state': 'Hadley, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbee'), 'city-state/county': 'Hampden, MA/Hampden', 'city-state': 'Hampden, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbef'), 'city-state/county': 'Hardwick, MA/Worcester', 'city-state': 'Hardwick, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbf0'), 'city-state/county': 'Hatfield, MA/Hampshire', 'city-state': 'Hatfield, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbf1'), 'city-state/county': 'Haydenville, MA/Hampshire', 'city-state': 'Haydenville, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbf2'), 'city-state/county': 'Holyoke, MA/Hampden', 'city-state': 'Holyoke, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbf3'), 'city-state/county': 'Huntington, MA/Hampshire', 'city-state': 'Huntington, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbf4'), 'city-state/county': 'Leeds, MA/Hampshire', 'city-state': 'Leeds, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbf5'), 'city-state/county': 'Leverett, MA/Franklin', 'city-state': 'Leverett, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbf6'), 'city-state/county': 'Ludlow, MA/Hampden', 'city-state': 'Ludlow, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbf7'), 'city-state/county': 'Monson, MA/Hampden', 'city-state': 'Monson, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbf8'), 'city-state/county': 'North Amherst, MA/Hampshire', 'city-state': 'North Amherst, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbf9'), 'city-state/county': 'Northampton, MA/Hampshire', 'city-state': 'Northampton, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbfa'), 'city-state/county': 'Florence, MA/Hampshire', 'city-state': 'Florence, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbfb'), 'city-state/county': 'North Hatfield, MA/Hampshire', 'city-state': 'North Hatfield, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbfc'), 'city-state/county': 'Oakham, MA/Worcester', 'city-state': 'Oakham, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbfd'), 'city-state/county': 'Palmer, MA/Hampden', 'city-state': 'Palmer, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbfe'), 'city-state/county': 'Plainfield, MA/Hampshire', 'city-state': 'Plainfield, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fbff'), 'city-state/county': 'Russell, MA/Hampden', 'city-state': 'Russell, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc00'), 'city-state/county': 'Shutesbury, MA/Franklin', 'city-state': 'Shutesbury, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc01'), 'city-state/county': 'Southampton, MA/Hampshire', 'city-state': 'Southampton, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc02'), 'city-state/county': 'South Barre, MA/Worcester', 'city-state': 'South Barre, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc03'), 'city-state/county': 'South Hadley, MA/Hampshire', 'city-state': 'South Hadley, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc04'), 'city-state/county': 'Southwick, MA/Hampden', 'city-state': 'Southwick, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc05'), 'city-state/county': 'Thorndike, MA/Hampden', 'city-state': 'Thorndike, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc06'), 'city-state/county': 'Three Rivers, MA/Hampden', 'city-state': 'Three Rivers, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc07'), 'city-state/county': 'Wales, MA/Hampden', 'city-state': 'Wales, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc08'), 'city-state/county': 'Ware, MA/Hampshire', 'city-state': 'Ware, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc09'), 'city-state/county': 'Warren, MA/Worcester', 'city-state': 'Warren, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc0a'), 'city-state/county': 'West Chesterfield, MA/Hampshire', 'city-state': 'West Chesterfield, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc0b'), 'city-state/county': 'Westfield, MA/Hampden', 'city-state': 'Westfield, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc0c'), 'city-state/county': 'Westfield, MA/Hampden', 'city-state': 'Westfield, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc0d'), 'city-state/county': 'West Hatfield, MA/Hampshire', 'city-state': 'West Hatfield, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc0e'), 'city-state/county': 'West Springfield, MA/Hampden', 'city-state': 'West Springfield, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc0f'), 'city-state/county': 'West Warren, MA/Worcester', 'city-state': 'West Warren, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc10'), 'city-state/county': 'Whately, MA/Franklin', 'city-state': 'Whately, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc11'), 'city-state/county': 'Wheelwright, MA/Worcester', 'city-state': 'Wheelwright, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc12'), 'city-state/county': 'Wilbraham, MA/Hampden', 'city-state': 'Wilbraham, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc13'), 'city-state/county': 'Williamsburg, MA/Hampshire', 'city-state': 'Williamsburg, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc14'), 'city-state/county': 'Woronoco, MA/Hampden', 'city-state': 'Woronoco, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc15'), 'city-state/county': 'Worthington, MA/Hampshire', 'city-state': 'Worthington, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc16'), 'city-state/county': 'Springfield, MA/Hampden', 'city-state': 'Springfield, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc17'), 'city-state/county': 'Springfield, MA/Hampden', 'city-state': 'Springfield, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc18'), 'city-state/county': 'Longmeadow, MA/Hampden', 'city-state': 'Longmeadow, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc19'), 'city-state/county': 'Longmeadow, MA/Hampden', 'city-state': 'Longmeadow, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc1a'), 'city-state/county': 'Indian Orchard, MA/Hampden', 'city-state': 'Indian Orchard, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc1b'), 'city-state/county': 'Pittsfield, MA/Berkshire', 'city-state': 'Pittsfield, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc1c'), 'city-state/county': 'Adams, MA/Berkshire', 'city-state': 'Adams, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc1d'), 'city-state/county': 'Ashley Falls, MA/Berkshire', 'city-state': 'Ashley Falls, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc1e'), 'city-state/county': 'Becket, MA/Berkshire', 'city-state': 'Becket, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc1f'), 'city-state/county': 'Berkshire, MA/Berkshire', 'city-state': 'Berkshire, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc20'), 'city-state/county': 'Cheshire, MA/Berkshire', 'city-state': 'Cheshire, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc21'), 'city-state/county': 'Dalton, MA/Berkshire', 'city-state': 'Dalton, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc22'), 'city-state/county': 'Glendale, MA/Berkshire', 'city-state': 'Glendale, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc23'), 'city-state/county': 'Great Barrington, MA/Berkshire', 'city-state': 'Great Barrington, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc24'), 'city-state/county': 'Hinsdale, MA/Berkshire', 'city-state': 'Hinsdale, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc25'), 'city-state/county': 'Housatonic, MA/Berkshire', 'city-state': 'Housatonic, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc26'), 'city-state/county': 'Lanesboro, MA/Berkshire', 'city-state': 'Lanesboro, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc27'), 'city-state/county': 'Lee, MA/Berkshire', 'city-state': 'Lee, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc28'), 'city-state/county': 'Lee, MA/Berkshire', 'city-state': 'Lee, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc29'), 'city-state/county': 'Lenox, MA/Berkshire', 'city-state': 'Lenox, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc2a'), 'city-state/county': 'Lenox Dale, MA/Berkshire', 'city-state': 'Lenox Dale, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc2b'), 'city-state/county': 'Middlefield, MA/Hampshire', 'city-state': 'Middlefield, MA', 'county': 'Hampshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc2c'), 'city-state/county': 'Mill River, MA/Berkshire', 'city-state': 'Mill River, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc2d'), 'city-state/county': 'Monterey, MA/Berkshire', 'city-state': 'Monterey, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc2e'), 'city-state/county': 'North Adams, MA/Berkshire', 'city-state': 'North Adams, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc2f'), 'city-state/county': 'North Egremont, MA/Berkshire', 'city-state': 'North Egremont, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc30'), 'city-state/county': 'Otis, MA/Berkshire', 'city-state': 'Otis, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc31'), 'city-state/county': 'Richmond, MA/Berkshire', 'city-state': 'Richmond, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc32'), 'city-state/county': 'Sandisfield, MA/Berkshire', 'city-state': 'Sandisfield, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc33'), 'city-state/county': 'Savoy, MA/Berkshire', 'city-state': 'Savoy, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc34'), 'city-state/county': 'Sheffield, MA/Berkshire', 'city-state': 'Sheffield, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc35'), 'city-state/county': 'South Egremont, MA/Berkshire', 'city-state': 'South Egremont, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc36'), 'city-state/county': 'Southfield, MA/Berkshire', 'city-state': 'Southfield, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc37'), 'city-state/county': 'South Lee, MA/Berkshire', 'city-state': 'South Lee, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc38'), 'city-state/county': 'Stockbridge, MA/Berkshire', 'city-state': 'Stockbridge, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc39'), 'city-state/county': 'Tyringham, MA/Berkshire', 'city-state': 'Tyringham, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc3a'), 'city-state/county': 'West Stockbridge, MA/Berkshire', 'city-state': 'West Stockbridge, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc3b'), 'city-state/county': 'Williamstown, MA/Berkshire', 'city-state': 'Williamstown, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc3c'), 'city-state/county': 'Windsor, MA/Berkshire', 'city-state': 'Windsor, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc3d'), 'city-state/county': 'Greenfield, MA/Franklin', 'city-state': 'Greenfield, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc3e'), 'city-state/county': 'Greenfield, MA/Franklin', 'city-state': 'Greenfield, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc3f'), 'city-state/county': 'Ashfield, MA/Franklin', 'city-state': 'Ashfield, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc40'), 'city-state/county': 'Athol, MA/Worcester', 'city-state': 'Athol, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc41'), 'city-state/county': 'Bernardston, MA/Franklin', 'city-state': 'Bernardston, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc42'), 'city-state/county': 'Buckland, MA/Franklin', 'city-state': 'Buckland, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc43'), 'city-state/county': 'Charlemont, MA/Franklin', 'city-state': 'Charlemont, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc44'), 'city-state/county': 'Colrain, MA/Franklin', 'city-state': 'Colrain, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc45'), 'city-state/county': 'Conway, MA/Franklin', 'city-state': 'Conway, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc46'), 'city-state/county': 'Deerfield, MA/Franklin', 'city-state': 'Deerfield, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc47'), 'city-state/county': 'Drury, MA/Berkshire', 'city-state': 'Drury, MA', 'county': 'Berkshire'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc48'), 'city-state/county': 'Erving, MA/Franklin', 'city-state': 'Erving, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc49'), 'city-state/county': 'Heath, MA/Franklin', 'city-state': 'Heath, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc4a'), 'city-state/county': 'Lake Pleasant, MA/Franklin', 'city-state': 'Lake Pleasant, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc4b'), 'city-state/county': 'Millers Falls, MA/Franklin', 'city-state': 'Millers Falls, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc4c'), 'city-state/county': 'Monroe Bridge, MA/Franklin', 'city-state': 'Monroe Bridge, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc4d'), 'city-state/county': 'Montague, MA/Franklin', 'city-state': 'Montague, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc4e'), 'city-state/county': 'Gill, MA/Franklin', 'city-state': 'Gill, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc4f'), 'city-state/county': 'New Salem, MA/Franklin', 'city-state': 'New Salem, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc50'), 'city-state/county': 'Northfield, MA/Franklin', 'city-state': 'Northfield, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc51'), 'city-state/county': 'Orange, MA/Franklin', 'city-state': 'Orange, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc52'), 'city-state/county': 'Petersham, MA/Worcester', 'city-state': 'Petersham, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc53'), 'city-state/county': 'Rowe, MA/Franklin', 'city-state': 'Rowe, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc54'), 'city-state/county': 'Royalston, MA/Worcester', 'city-state': 'Royalston, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc55'), 'city-state/county': 'Shelburne Falls, MA/Franklin', 'city-state': 'Shelburne Falls, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc56'), 'city-state/county': 'South Deerfield, MA/Franklin', 'city-state': 'South Deerfield, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc57'), 'city-state/county': 'Sunderland, MA/Franklin', 'city-state': 'Sunderland, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc58'), 'city-state/county': 'Turners Falls, MA/Franklin', 'city-state': 'Turners Falls, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc59'), 'city-state/county': 'Warwick, MA/Franklin', 'city-state': 'Warwick, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc5a'), 'city-state/county': 'Wendell, MA/Franklin', 'city-state': 'Wendell, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc5b'), 'city-state/county': 'Wendell Depot, MA/Franklin', 'city-state': 'Wendell Depot, MA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc5c'), 'city-state/county': 'Fitchburg, MA/Worcester', 'city-state': 'Fitchburg, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc5d'), 'city-state/county': 'Ashburnham, MA/Worcester', 'city-state': 'Ashburnham, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc5e'), 'city-state/county': 'Ashby, MA/Middlesex', 'city-state': 'Ashby, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc5f'), 'city-state/county': 'Ayer, MA/Middlesex', 'city-state': 'Ayer, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc60'), 'city-state/county': 'Devens, MA/Worcester', 'city-state': 'Devens, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc61'), 'city-state/county': 'Baldwinville, MA/Worcester', 'city-state': 'Baldwinville, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc62'), 'city-state/county': 'East Templeton, MA/Worcester', 'city-state': 'East Templeton, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc63'), 'city-state/county': 'Gardner, MA/Worcester', 'city-state': 'Gardner, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc64'), 'city-state/county': 'Westminster, MA/Worcester', 'city-state': 'Westminster, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc65'), 'city-state/county': 'Groton, MA/Middlesex', 'city-state': 'Groton, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc66'), 'city-state/county': 'Harvard, MA/Worcester', 'city-state': 'Harvard, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc67'), 'city-state/county': 'Hubbardston, MA/Worcester', 'city-state': 'Hubbardston, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc68'), 'city-state/county': 'Leominster, MA/Worcester', 'city-state': 'Leominster, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc69'), 'city-state/county': 'Littleton, MA/Middlesex', 'city-state': 'Littleton, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc6a'), 'city-state/county': 'Lunenburg, MA/Worcester', 'city-state': 'Lunenburg, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc6b'), 'city-state/county': 'Pepperell, MA/Middlesex', 'city-state': 'Pepperell, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc6c'), 'city-state/county': 'Shirley, MA/Middlesex', 'city-state': 'Shirley, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc6d'), 'city-state/county': 'Still River, MA/Worcester', 'city-state': 'Still River, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc6e'), 'city-state/county': 'Templeton, MA/Worcester', 'city-state': 'Templeton, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc6f'), 'city-state/county': 'Townsend, MA/Middlesex', 'city-state': 'Townsend, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc70'), 'city-state/county': 'West Groton, MA/Middlesex', 'city-state': 'West Groton, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc71'), 'city-state/county': 'West Townsend, MA/Middlesex', 'city-state': 'West Townsend, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc72'), 'city-state/county': 'Winchendon, MA/Worcester', 'city-state': 'Winchendon, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc73'), 'city-state/county': 'Winchendon Springs, MA/Worcester', 'city-state': 'Winchendon Springs, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc74'), 'city-state/county': 'Auburn, MA/Worcester', 'city-state': 'Auburn, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc75'), 'city-state/county': 'Berlin, MA/Worcester', 'city-state': 'Berlin, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc76'), 'city-state/county': 'Blackstone, MA/Worcester', 'city-state': 'Blackstone, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc77'), 'city-state/county': 'Boylston, MA/Worcester', 'city-state': 'Boylston, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc78'), 'city-state/county': 'Brookfield, MA/Worcester', 'city-state': 'Brookfield, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc79'), 'city-state/county': 'Charlton, MA/Worcester', 'city-state': 'Charlton, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc7a'), 'city-state/county': 'Charlton City, MA/Worcester', 'city-state': 'Charlton City, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc7b'), 'city-state/county': 'Charlton Depot, MA/Worcester', 'city-state': 'Charlton Depot, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc7c'), 'city-state/county': 'Clinton, MA/Worcester', 'city-state': 'Clinton, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc7d'), 'city-state/county': 'East Brookfield, MA/Worcester', 'city-state': 'East Brookfield, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc7e'), 'city-state/county': 'Douglas, MA/Worcester', 'city-state': 'Douglas, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc7f'), 'city-state/county': 'East Princeton, MA/Worcester', 'city-state': 'East Princeton, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc80'), 'city-state/county': 'Fiskdale, MA/Worcester', 'city-state': 'Fiskdale, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc81'), 'city-state/county': 'Grafton, MA/Worcester', 'city-state': 'Grafton, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc82'), 'city-state/county': 'Holden, MA/Worcester', 'city-state': 'Holden, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc83'), 'city-state/county': 'Holland, MA/Hampden', 'city-state': 'Holland, MA', 'county': 'Hampden'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc84'), 'city-state/county': 'Jefferson, MA/Worcester', 'city-state': 'Jefferson, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc85'), 'city-state/county': 'Lancaster, MA/Worcester', 'city-state': 'Lancaster, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc86'), 'city-state/county': 'Leicester, MA/Worcester', 'city-state': 'Leicester, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc87'), 'city-state/county': 'Linwood, MA/Worcester', 'city-state': 'Linwood, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc88'), 'city-state/county': 'Linwood, MA/Worcester', 'city-state': 'Linwood, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc89'), 'city-state/county': 'Manchaug, MA/Worcester', 'city-state': 'Manchaug, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc8a'), 'city-state/county': 'Millbury, MA/Worcester', 'city-state': 'Millbury, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc8b'), 'city-state/county': 'Millbury, MA/Worcester', 'city-state': 'Millbury, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc8c'), 'city-state/county': 'Millville, MA/Worcester', 'city-state': 'Millville, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc8d'), 'city-state/county': 'New Braintree, MA/Worcester', 'city-state': 'New Braintree, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc8e'), 'city-state/county': 'Northborough, MA/Worcester', 'city-state': 'Northborough, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc8f'), 'city-state/county': 'Northbridge, MA/Worcester', 'city-state': 'Northbridge, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc90'), 'city-state/county': 'North Brookfield, MA/Worcester', 'city-state': 'North Brookfield, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc91'), 'city-state/county': 'North Grafton, MA/Worcester', 'city-state': 'North Grafton, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc92'), 'city-state/county': 'North Oxford, MA/Worcester', 'city-state': 'North Oxford, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc93'), 'city-state/county': 'North Uxbridge, MA/Worcester', 'city-state': 'North Uxbridge, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc94'), 'city-state/county': 'Oxford, MA/Worcester', 'city-state': 'Oxford, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc95'), 'city-state/county': 'Princeton, MA/Worcester', 'city-state': 'Princeton, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc96'), 'city-state/county': 'Rochdale, MA/Worcester', 'city-state': 'Rochdale, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc97'), 'city-state/county': 'Rutland, MA/Worcester', 'city-state': 'Rutland, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc98'), 'city-state/county': 'Shrewsbury, MA/Worcester', 'city-state': 'Shrewsbury, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc99'), 'city-state/county': 'Southbridge, MA/Worcester', 'city-state': 'Southbridge, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc9a'), 'city-state/county': 'South Grafton, MA/Worcester', 'city-state': 'South Grafton, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc9b'), 'city-state/county': 'South Lancaster, MA/Worcester', 'city-state': 'South Lancaster, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc9c'), 'city-state/county': 'Spencer, MA/Worcester', 'city-state': 'Spencer, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc9d'), 'city-state/county': 'Sterling, MA/Worcester', 'city-state': 'Sterling, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc9e'), 'city-state/county': 'Sturbridge, MA/Worcester', 'city-state': 'Sturbridge, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fc9f'), 'city-state/county': 'Sturbridge, MA/Worcester', 'city-state': 'Sturbridge, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fca0'), 'city-state/county': 'Upton, MA/Worcester', 'city-state': 'Upton, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fca1'), 'city-state/county': 'Uxbridge, MA/Worcester', 'city-state': 'Uxbridge, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fca2'), 'city-state/county': 'Webster, MA/Worcester', 'city-state': 'Webster, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fca3'), 'city-state/county': 'Dudley, MA/Worcester', 'city-state': 'Dudley, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fca4'), 'city-state/county': 'Westborough, MA/Worcester', 'city-state': 'Westborough, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fca5'), 'city-state/county': 'West Boylston, MA/Worcester', 'city-state': 'West Boylston, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fca6'), 'city-state/county': 'West Brookfield, MA/Worcester', 'city-state': 'West Brookfield, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fca7'), 'city-state/county': 'West Millbury, MA/Worcester', 'city-state': 'West Millbury, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fca8'), 'city-state/county': 'Whitinsville, MA/Worcester', 'city-state': 'Whitinsville, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fca9'), 'city-state/county': 'Sutton, MA/Worcester', 'city-state': 'Sutton, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcaa'), 'city-state/county': 'Worcester, MA/Worcester', 'city-state': 'Worcester, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcab'), 'city-state/county': 'Worcester, MA/Worcester', 'city-state': 'Worcester, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcac'), 'city-state/county': 'Cherry Valley, MA/Worcester', 'city-state': 'Cherry Valley, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcad'), 'city-state/county': 'Paxton, MA/Worcester', 'city-state': 'Paxton, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcae'), 'city-state/county': 'Framingham, MA/Middlesex', 'city-state': 'Framingham, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcaf'), 'city-state/county': 'Village Of Nagog Woods, MA/Middlesex', 'city-state': 'Village Of Nagog Woods, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcb0'), 'city-state/county': 'Boxborough, MA/Middlesex', 'city-state': 'Boxborough, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcb1'), 'city-state/county': 'Acton, MA/Middlesex', 'city-state': 'Acton, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcb2'), 'city-state/county': 'Ashland, MA/Middlesex', 'city-state': 'Ashland, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcb3'), 'city-state/county': 'Bedford, MA/Middlesex', 'city-state': 'Bedford, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcb4'), 'city-state/county': 'Bedford, MA/Middlesex', 'city-state': 'Bedford, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcb5'), 'city-state/county': 'Hanscom Afb, MA/Middlesex', 'city-state': 'Hanscom Afb, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcb6'), 'city-state/county': 'Bolton, MA/Worcester', 'city-state': 'Bolton, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcb7'), 'city-state/county': 'Carlisle, MA/Middlesex', 'city-state': 'Carlisle, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcb8'), 'city-state/county': 'Concord, MA/Middlesex', 'city-state': 'Concord, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcb9'), 'city-state/county': 'Fayville, MA/Worcester', 'city-state': 'Fayville, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcba'), 'city-state/county': 'Holliston, MA/Middlesex', 'city-state': 'Holliston, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcbb'), 'city-state/county': 'Hopedale, MA/Worcester', 'city-state': 'Hopedale, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcbc'), 'city-state/county': 'Hopkinton, MA/Middlesex', 'city-state': 'Hopkinton, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcbd'), 'city-state/county': 'Hudson, MA/Middlesex', 'city-state': 'Hudson, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcbe'), 'city-state/county': 'Marlborough, MA/Middlesex', 'city-state': 'Marlborough, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcbf'), 'city-state/county': 'Maynard, MA/Middlesex', 'city-state': 'Maynard, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcc0'), 'city-state/county': 'Mendon, MA/Worcester', 'city-state': 'Mendon, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcc1'), 'city-state/county': 'Milford, MA/Worcester', 'city-state': 'Milford, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcc2'), 'city-state/county': 'Natick, MA/Middlesex', 'city-state': 'Natick, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcc3'), 'city-state/county': 'Sherborn, MA/Middlesex', 'city-state': 'Sherborn, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcc4'), 'city-state/county': 'Southborough, MA/Worcester', 'city-state': 'Southborough, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcc5'), 'city-state/county': 'Southborough, MA/Worcester', 'city-state': 'Southborough, MA', 'county': 'Worcester'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcc6'), 'city-state/county': 'Lincoln, MA/Middlesex', 'city-state': 'Lincoln, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcc7'), 'city-state/county': 'Stow, MA/Middlesex', 'city-state': 'Stow, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcc8'), 'city-state/county': 'Sudbury, MA/Middlesex', 'city-state': 'Sudbury, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcc9'), 'city-state/county': 'Wayland, MA/Middlesex', 'city-state': 'Wayland, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcca'), 'city-state/county': 'Woodville, MA/Middlesex', 'city-state': 'Woodville, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fccb'), 'city-state/county': 'Woburn, MA/Middlesex', 'city-state': 'Woburn, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fccc'), 'city-state/county': 'Woburn, MA/Middlesex', 'city-state': 'Woburn, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fccd'), 'city-state/county': 'Burlington, MA/Middlesex', 'city-state': 'Burlington, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcce'), 'city-state/county': 'Andover, MA/Essex', 'city-state': 'Andover, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fccf'), 'city-state/county': 'Billerica, MA/Middlesex', 'city-state': 'Billerica, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcd0'), 'city-state/county': 'Chelmsford, MA/Middlesex', 'city-state': 'Chelmsford, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcd1'), 'city-state/county': 'Dracut, MA/Middlesex', 'city-state': 'Dracut, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcd2'), 'city-state/county': 'Dunstable, MA/Middlesex', 'city-state': 'Dunstable, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcd3'), 'city-state/county': 'Haverhill, MA/Essex', 'city-state': 'Haverhill, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcd4'), 'city-state/county': 'Haverhill, MA/Essex', 'city-state': 'Haverhill, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcd5'), 'city-state/county': 'Haverhill, MA/Essex', 'city-state': 'Haverhill, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcd6'), 'city-state/county': 'Haverhill, MA/Essex', 'city-state': 'Haverhill, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcd7'), 'city-state/county': 'Georgetown, MA/Essex', 'city-state': 'Georgetown, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcd8'), 'city-state/county': 'Groveland, MA/Essex', 'city-state': 'Groveland, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcd9'), 'city-state/county': 'Lawrence, MA/Essex', 'city-state': 'Lawrence, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcda'), 'city-state/county': 'Methuen, MA/Essex', 'city-state': 'Methuen, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcdb'), 'city-state/county': 'North Andover, MA/Essex', 'city-state': 'North Andover, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcdc'), 'city-state/county': 'Lowell, MA/Middlesex', 'city-state': 'Lowell, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcdd'), 'city-state/county': 'Merrimac, MA/Essex', 'city-state': 'Merrimac, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcde'), 'city-state/county': 'North Billerica, MA/Middlesex', 'city-state': 'North Billerica, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcdf'), 'city-state/county': 'North Chelmsford, MA/Middlesex', 'city-state': 'North Chelmsford, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fce0'), 'city-state/county': 'North Reading, MA/Middlesex', 'city-state': 'North Reading, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fce1'), 'city-state/county': 'Nutting Lake, MA/Middlesex', 'city-state': 'Nutting Lake, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fce2'), 'city-state/county': 'Pinehurst, MA/Middlesex', 'city-state': 'Pinehurst, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fce3'), 'city-state/county': 'Reading, MA/Middlesex', 'city-state': 'Reading, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fce4'), 'city-state/county': 'Tewksbury, MA/Middlesex', 'city-state': 'Tewksbury, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fce5'), 'city-state/county': 'Tyngsboro, MA/Middlesex', 'city-state': 'Tyngsboro, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fce6'), 'city-state/county': 'Wakefield, MA/Middlesex', 'city-state': 'Wakefield, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fce7'), 'city-state/county': 'West Boxford, MA/Essex', 'city-state': 'West Boxford, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fce8'), 'city-state/county': 'Westford, MA/Middlesex', 'city-state': 'Westford, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fce9'), 'city-state/county': 'Wilmington, MA/Middlesex', 'city-state': 'Wilmington, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcea'), 'city-state/county': 'Winchester, MA/Middlesex', 'city-state': 'Winchester, MA', 'county': 'Middlesex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fceb'), 'city-state/county': 'Lynn, MA/Essex', 'city-state': 'Lynn, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcec'), 'city-state/county': 'Lynn, MA/Essex', 'city-state': 'Lynn, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fced'), 'city-state/county': 'Lynn, MA/Essex', 'city-state': 'Lynn, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcee'), 'city-state/county': 'Saugus, MA/Essex', 'city-state': 'Saugus, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcef'), 'city-state/county': 'Swampscott, MA/Essex', 'city-state': 'Swampscott, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcf0'), 'city-state/county': 'Nahant, MA/Essex', 'city-state': 'Nahant, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcf1'), 'city-state/county': 'Amesbury, MA/Essex', 'city-state': 'Amesbury, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcf2'), 'city-state/county': 'Beverly, MA/Essex', 'city-state': 'Beverly, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcf3'), 'city-state/county': 'Boxford, MA/Essex', 'city-state': 'Boxford, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcf4'), 'city-state/county': 'Byfield, MA/Essex', 'city-state': 'Byfield, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcf5'), 'city-state/county': 'Danvers, MA/Essex', 'city-state': 'Danvers, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcf6'), 'city-state/county': 'Essex, MA/Essex', 'city-state': 'Essex, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcf7'), 'city-state/county': 'Gloucester, MA/Essex', 'city-state': 'Gloucester, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcf8'), 'city-state/county': 'Hamilton, MA/Essex', 'city-state': 'Hamilton, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcf9'), 'city-state/county': 'Hathorne, MA/Essex', 'city-state': 'Hathorne, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcfa'), 'city-state/county': 'Ipswich, MA/Essex', 'city-state': 'Ipswich, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcfb'), 'city-state/county': 'Lynnfield, MA/Essex', 'city-state': 'Lynnfield, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcfc'), 'city-state/county': 'Manchester, MA/Essex', 'city-state': 'Manchester, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcfd'), 'city-state/county': 'Marblehead, MA/Essex', 'city-state': 'Marblehead, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcfe'), 'city-state/county': 'Middleton, MA/Essex', 'city-state': 'Middleton, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fcff'), 'city-state/county': 'Newburyport, MA/Essex', 'city-state': 'Newburyport, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd00'), 'city-state/county': 'Newburyport, MA/Essex', 'city-state': 'Newburyport, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd01'), 'city-state/county': 'Newbury, MA/Essex', 'city-state': 'Newbury, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd02'), 'city-state/county': 'Salisbury, MA/Essex', 'city-state': 'Salisbury, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd03'), 'city-state/county': 'Peabody, MA/Essex', 'city-state': 'Peabody, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd04'), 'city-state/county': 'Prides Crossing, MA/Essex', 'city-state': 'Prides Crossing, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd05'), 'city-state/county': 'Rockport, MA/Essex', 'city-state': 'Rockport, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd06'), 'city-state/county': 'Rowley, MA/Essex', 'city-state': 'Rowley, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd07'), 'city-state/county': 'Salem, MA/Essex', 'city-state': 'Salem, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd08'), 'city-state/county': 'South Hamilton, MA/Essex', 'city-state': 'South Hamilton, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd09'), 'city-state/county': 'Topsfield, MA/Essex', 'city-state': 'Topsfield, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd0a'), 'city-state/county': 'Wenham, MA/Essex', 'city-state': 'Wenham, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd0b'), 'city-state/county': 'West Newbury, MA/Essex', 'city-state': 'West Newbury, MA', 'county': 'Essex'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd0c'), 'city-state/county': 'Accord, MA/Plymouth', 'city-state': 'Accord, MA', 'county': 'Plymouth'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd0d'), 'city-state/county': 'Bellingham, MA/Norfolk', 'city-state': 'Bellingham, MA', 'county': 'Norfolk'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd0e'), 'city-state/county': 'Brant Rock, MA/Plymouth', 'city-state': 'Brant Rock, MA', 'county': 'Plymouth'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd0f'), 'city-state/county': 'Canton, MA/Norfolk', 'city-state': 'Canton, MA', 'county': 'Norfolk'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd10'), 'city-state/county': 'Cohasset, MA/Norfolk', 'city-state': 'Cohasset, MA', 'county': 'Norfolk'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd11'), 'city-state/county': 'Dedham, MA/Norfolk', 'city-state': 'Dedham, MA', 'county': 'Norfolk'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd12'), 'city-state/county': 'Dover, MA/Norfolk', 'city-state': 'Dover, MA', 'county': 'Norfolk'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd13'), 'city-state/county': 'East Mansfield, MA/Bristol', 'city-state': 'East Mansfield, MA', 'county': 'Bristol'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd14'), 'city-state/county': 'East Walpole, MA/Norfolk', 'city-state': 'East Walpole, MA', 'county': 'Norfolk'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd15'), 'city-state/county': 'Foxboro, MA/Norfolk', 'city-state': 'Foxboro, MA', 'county': 'Norfolk'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd16'), 'city-state/county': 'Franklin, MA/Norfolk', 'city-state': 'Franklin, MA', 'county': 'Norfolk'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd17'), 'city-state/county': 'Greenbush, MA/Plymouth', 'city-state': 'Greenbush, MA', 'county': 'Plymouth'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd18'), 'city-state/county': 'Green Harbor, MA/Plymouth', 'city-state': 'Green Harbor, MA', 'county': 'Plymouth'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd19'), 'city-state/county': 'Hingham, MA/Plymouth', 'city-state': 'Hingham, MA', 'county': 'Plymouth'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd1a'), 'city-state/county': 'Hingham, MA/Plymouth', 'city-state': 'Hingham, MA', 'county': 'Plymouth'}
# {'_id': ObjectId('5e1aa8bd051df6979a54fd1b'), 'city-state/county': 'Hull, MA/Plymouth', 'city-state': 'Hull, MA', 'county': 'Plymouth'}
# ...
# {'_id': ObjectId('5e1aa8bd051df6979a5599b1'), 'city-state/county': 'Ruston, WA/Pierce', 'city-state': 'Ruston, WA', 'county': 'Pierce'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599b2'), 'city-state/county': 'Fife, WA/Pierce', 'city-state': 'Fife, WA', 'county': 'Pierce'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599b3'), 'city-state/county': 'Joint Base Lewis Mcchord, Lewis Mcchord, Madigan Hosp, Madigan Hospital, WA/Pierce', 'city-state': 'Joint Base Lewis Mcchord, Lewis Mcchord, Madigan Hosp, Madigan Hospital, WA', 'county': 'Pierce'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599b4'), 'city-state/county': 'Fort Lewis, Ft Lewis, Joint Base Lewis Mcchord, Lewis Mcchord, WA/Pierce', 'city-state': 'Fort Lewis, Ft Lewis, Joint Base Lewis Mcchord, Lewis Mcchord, WA', 'county': 'Pierce'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599b5'), 'city-state/county': 'Joint Base Lewis Mcchord, Lewis Mcchord, Tacoma, WA/Pierce', 'city-state': 'Joint Base Lewis Mcchord, Lewis Mcchord, Tacoma, WA', 'county': 'Pierce'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599b6'), 'city-state/county': 'Joint Base Lewis Mcchord, Lewis Mcchord, Mcchord Afb, Tacoma, WA/Pierce', 'city-state': 'Joint Base Lewis Mcchord, Lewis Mcchord, Mcchord Afb, Tacoma, WA', 'county': 'Pierce'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599b7'), 'city-state/county': 'Parkland, WA/Pierce', 'city-state': 'Parkland, WA', 'county': 'Pierce'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599b8'), 'city-state/county': 'University Pl, University Place, WA/Pierce', 'city-state': 'University Pl, University Place, WA', 'county': 'Pierce'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599b9'), 'city-state/county': 'Fircrest, University Pl, University Place, WA/Pierce', 'city-state': 'Fircrest, University Pl, University Place, WA', 'county': 'Pierce'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599ba'), 'city-state/county': 'Tacoma, University Pl, WA/Pierce', 'city-state': 'Tacoma, University Pl, WA', 'county': 'Pierce'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599bb'), 'city-state/county': 'Oakbrook, Tacoma, WA/Pierce', 'city-state': 'Oakbrook, Tacoma, WA', 'county': 'Pierce'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599bc'), 'city-state/county': 'Copalis Xing, WA/Grays Harbor', 'city-state': 'Copalis Xing, WA', 'county': 'Grays Harbor'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599bd'), 'city-state/county': 'Ocean City, WA/Grays Harbor', 'city-state': 'Ocean City, WA', 'county': 'Grays Harbor'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599be'), 'city-state/county': 'Skok, Skokomish Nation, WA/Mason', 'city-state': 'Skok, Skokomish Nation, WA', 'county': 'Mason'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599bf'), 'city-state/county': 'Cook, WA/Klickitat', 'city-state': 'Cook, WA', 'county': 'Klickitat'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599c0'), 'city-state/county': 'N Bonneville, WA/Skamania', 'city-state': 'N Bonneville, WA', 'county': 'Skamania'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599c1'), 'city-state/county': 'E Wenatchee, Wenatchee, WA/Douglas', 'city-state': 'E Wenatchee, Wenatchee, WA', 'county': 'Douglas'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599c2'), 'city-state/county': 'Union Gap, WA/Yakima', 'city-state': 'Union Gap, WA', 'county': 'Yakima'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599c3'), 'city-state/county': 'Gleed, WA/Yakima', 'city-state': 'Gleed, WA', 'county': 'Yakima'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599c4'), 'city-state/county': 'Goose Prairie, WA/Yakima', 'city-state': 'Goose Prairie, WA', 'county': 'Yakima'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599c5'), 'city-state/county': 'S Cle Elum, WA/Kittitas', 'city-state': 'S Cle Elum, WA', 'county': 'Kittitas'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599c6'), 'city-state/county': 'Airway Hgts, WA/Spokane', 'city-state': 'Airway Hgts, WA', 'county': 'Spokane'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599c7'), 'city-state/county': 'Fairchild Afb, WA/Spokane', 'city-state': 'Fairchild Afb, WA', 'county': 'Spokane'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599c8'), 'city-state/county': 'Liberty Lake, Spokane Valley, Spokane Vly, WA/Spokane', 'city-state': 'Liberty Lake, Spokane Valley, Spokane Vly, WA', 'county': 'Spokane'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599c9'), 'city-state/county': 'Sprague, WA/Whitman', 'city-state': 'Sprague, WA', 'county': 'Whitman'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599ca'), 'city-state/county': 'Espanola, WA/Spokane', 'city-state': 'Espanola, WA', 'county': 'Spokane'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599cb'), 'city-state/county': 'Nine Mile Fls, WA/Stevens', 'city-state': 'Nine Mile Fls, WA', 'county': 'Stevens'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599cc'), 'city-state/county': 'City Of Spokane Valley, Spokane Valley, Spokane Vly, WA/Spokane', 'city-state': 'City Of Spokane Valley, Spokane Valley, Spokane Vly, WA', 'county': 'Spokane'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599cd'), 'city-state/county': 'City Of Spokane Valley, Spokane Valley, Spokane Vly, WA/Spokane', 'city-state': 'City Of Spokane Valley, Spokane Valley, Spokane Vly, WA', 'county': 'Spokane'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599ce'), 'city-state/county': 'Kettle Falls, WA/Ferry', 'city-state': 'Kettle Falls, WA', 'county': 'Ferry'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599cf'), 'city-state/county': 'Kettle Falls, WA/Ferry', 'city-state': 'Kettle Falls, WA', 'county': 'Ferry'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599d0'), 'city-state/county': 'Diamond, WA/Whitman', 'city-state': 'Diamond, WA', 'county': 'Whitman'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599d1'), 'city-state/county': 'Deer Meadows, Seven Bays, WA/Lincoln', 'city-state': 'Deer Meadows, Seven Bays, WA', 'county': 'Lincoln'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599d2'), 'city-state/county': 'Metaline Fls, WA/Pend Oreille', 'city-state': 'Metaline Fls, WA', 'county': 'Pend Oreille'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599d3'), 'city-state/county': 'Plaza, WA/Whitman', 'city-state': 'Plaza, WA', 'county': 'Whitman'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599d4'), 'city-state/county': 'Spokane Valley, Spokane Vly, WA/Spokane', 'city-state': 'Spokane Valley, Spokane Vly, WA', 'county': 'Spokane'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599d5'), 'city-state/county': 'Millwood, Spokane Valley, Spokane Vly, WA/Spokane', 'city-state': 'Millwood, Spokane Valley, Spokane Vly, WA', 'county': 'Spokane'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599d6'), 'city-state/county': 'Sunset Hill, WA/Spokane', 'city-state': 'Sunset Hill, WA', 'county': 'Spokane'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599d7'), 'city-state/county': 'Tri Cities, WA/Franklin', 'city-state': 'Tri Cities, WA', 'county': 'Franklin'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599d8'), 'city-state/county': 'Hatton, WA/Adams', 'city-state': 'Hatton, WA', 'county': 'Adams'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599d9'), 'city-state/county': 'Desert Aire, WA/Grant', 'city-state': 'Desert Aire, WA', 'county': 'Grant'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599da'), 'city-state/county': 'Lowden, WA/Walla Walla', 'city-state': 'Lowden, WA', 'county': 'Walla Walla'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599db'), 'city-state/county': 'Anchorage, Fort Richardson, Ft Richardson, AK/Anchorage Municipality', 'city-state': 'Anchorage, Fort Richardson, Ft Richardson, AK', 'county': 'Anchorage Municipality'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599dc'), 'city-state/county': 'Anchorage, Elmendorf Afb, AK/Anchorage Municipality', 'city-state': 'Anchorage, Elmendorf Afb, AK', 'county': 'Anchorage Municipality'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599dd'), 'city-state/county': 'King Salmon, AK/Lake and Peninsula', 'city-state': 'King Salmon, AK', 'county': 'Lake and Peninsula'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599de'), 'city-state/county': 'Nikolaevsk, AK/Kenai Peninsula', 'city-state': 'Nikolaevsk, AK', 'county': 'Kenai Peninsula'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599df'), 'city-state/county': 'Chuathbaluk, Stony River, AK/Bethel Census Area', 'city-state': 'Chuathbaluk, Stony River, AK', 'county': 'Bethel Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599e0'), 'city-state/county': 'Atmautluak, Napaskiak, Newtok, AK/Bethel Census Area', 'city-state': 'Atmautluak, Napaskiak, Newtok, AK', 'county': 'Bethel Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599e1'), 'city-state/county': 'Chignik Lagn, AK/Lake and Peninsula', 'city-state': 'Chignik Lagn, AK', 'county': 'Lake and Peninsula'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599e2'), 'city-state/county': 'Adak, Nelson Lagoon, AK/Aleutians East', 'city-state': 'Adak, Nelson Lagoon, AK', 'county': 'Aleutians East'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599e3'), 'city-state/county': 'Cooper Lndg, AK/Kenai Peninsula', 'city-state': 'Cooper Lndg, AK', 'county': 'Kenai Peninsula'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599e4'), 'city-state/county': 'Chenega Bay, AK/Valdez-Cordova Census Area', 'city-state': 'Chenega Bay, AK', 'county': 'Valdez-Cordova Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599e5'), 'city-state/county': 'Koliganek, Twin Hills, AK/Dillingham Census Area', 'city-state': 'Koliganek, Twin Hills, AK', 'county': 'Dillingham Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599e6'), 'city-state/county': 'Miers Lake, Slana, AK/Valdez-Cordova Census Area', 'city-state': 'Miers Lake, Slana, AK', 'county': 'Valdez-Cordova Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599e7'), 'city-state/county': 'Saint Paul Island, St George Is, St Paul Isle, AK/Aleutians West Census Area', 'city-state': 'Saint Paul Island, St George Is, St Paul Isle, AK', 'county': 'Aleutians West Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599e8'), 'city-state/county': 'English Bay, Fritz Creek, Halibut Cove, Kachemak, Nanwalek, Port Graham, AK/Kenai Peninsula', 'city-state': 'English Bay, Fritz Creek, Halibut Cove, Kachemak, Nanwalek, Port Graham, AK', 'county': 'Kenai Peninsula'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599e9'), 'city-state/county': 'Kokhanok, AK/Lake and Peninsula', 'city-state': 'Kokhanok, AK', 'county': 'Lake and Peninsula'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599ea'), 'city-state/county': 'Igiugig, AK/Bristol Bay', 'city-state': 'Igiugig, AK', 'county': 'Bristol Bay'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599eb'), 'city-state/county': 'Akhiok, Chiniak, AK/Kodiak Island', 'city-state': 'Akhiok, Chiniak, AK', 'county': 'Kodiak Island'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599ec'), 'city-state/county': 'Mountain Vlg, AK/Wade Hampton Census Area', 'city-state': 'Mountain Vlg, AK', 'county': 'Wade Hampton Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599ed'), 'city-state/county': 'Russian Msn, AK/Wade Hampton Census Area', 'city-state': 'Russian Msn, AK', 'county': 'Wade Hampton Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599ee'), 'city-state/county': 'Saint Paul, St Paul, St Paul Isle, AK/Aleutians West Census Area', 'city-state': 'Saint Paul, St Paul, St Paul Isle, AK', 'county': 'Aleutians West Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599ef'), 'city-state/county': 'Chickaloon, AK/Matanuska-Susitna', 'city-state': 'Chickaloon, AK', 'county': 'Matanuska-Susitna'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599f0'), 'city-state/county': 'Girdwood, AK/Valdez-Cordova Census Area', 'city-state': 'Girdwood, AK', 'county': 'Valdez-Cordova Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599f1'), 'city-state/county': 'Coldfoot, AK/Fairbanks North Star', 'city-state': 'Coldfoot, AK', 'county': 'Fairbanks North Star'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599f2'), 'city-state/county': 'Ft Wainwright, AK/Fairbanks North Star', 'city-state': 'Ft Wainwright, AK', 'county': 'Fairbanks North Star'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599f3'), 'city-state/county': 'Nenana, AK/Denali', 'city-state': 'Nenana, AK', 'county': 'Denali'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599f4'), 'city-state/county': 'Nenana, AK/Denali', 'city-state': 'Nenana, AK', 'county': 'Denali'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599f5'), 'city-state/county': 'Steese, AK/Fairbanks North Star', 'city-state': 'Steese, AK', 'county': 'Fairbanks North Star'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599f6'), 'city-state/county': 'Badger, AK/Fairbanks North Star', 'city-state': 'Badger, AK', 'county': 'Fairbanks North Star'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599f7'), 'city-state/county': 'Anaktuvuk, AK/North Slope', 'city-state': 'Anaktuvuk, AK', 'county': 'North Slope'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599f8'), 'city-state/county': 'Arctic Vlg, AK/Yukon-Koyukuk Census Area', 'city-state': 'Arctic Vlg, AK', 'county': 'Yukon-Koyukuk Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599f9'), 'city-state/county': 'Delta Jct, Delta Junction, AK/Southeast Fairbanks Census Area', 'city-state': 'Delta Jct, Delta Junction, AK', 'county': 'Southeast Fairbanks Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599fa'), 'city-state/county': 'Delta Jct, Dot Lake, AK/Southeast Fairbanks Census Area', 'city-state': 'Delta Jct, Dot Lake, AK', 'county': 'Southeast Fairbanks Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599fb'), 'city-state/county': 'Denali Park, AK/Denali', 'city-state': 'Denali Park, AK', 'county': 'Denali'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599fc'), 'city-state/county': 'Manley Spgs, AK/Yukon-Koyukuk Census Area', 'city-state': 'Manley Spgs, AK', 'county': 'Yukon-Koyukuk Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599fd'), 'city-state/county': 'Lk Minchumina, AK/Yukon-Koyukuk Census Area', 'city-state': 'Lk Minchumina, AK', 'county': 'Yukon-Koyukuk Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599fe'), 'city-state/county': 'Diomede, Golovin, Little Diomede, Ltl Diomede, AK/Nome Census Area', 'city-state': 'Diomede, Golovin, Little Diomede, Ltl Diomede, AK', 'county': 'Nome Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a5599ff'), 'city-state/county': 'Stevens Vlg, AK/Yukon-Koyukuk Census Area', 'city-state': 'Stevens Vlg, AK', 'county': 'Yukon-Koyukuk Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a559a00'), 'city-state/county': 'Mentasta Lake, AK/Southeast Fairbanks Census Area', 'city-state': 'Mentasta Lake, AK', 'county': 'Southeast Fairbanks Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a559a01'), 'city-state/county': 'White Mtn, AK/Nome Census Area', 'city-state': 'White Mtn, AK', 'county': 'Nome Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a559a02'), 'city-state/county': 'Brevig Msn, AK/Nome Census Area', 'city-state': 'Brevig Msn, AK', 'county': 'Nome Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a559a03'), 'city-state/county': 'Kupreanof, AK/Petersburg Census Area', 'city-state': 'Kupreanof, AK', 'county': 'Petersburg Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a559a04'), 'city-state/county': 'Prt Alexander, Sitka, AK/Petersburg Census Area', 'city-state': 'Prt Alexander, Sitka, AK', 'county': 'Petersburg Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a559a05'), 'city-state/county': 'Tenakee Spgs, AK/Hoonah-Angoon Census Area', 'city-state': 'Tenakee Spgs, AK', 'county': 'Hoonah-Angoon Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a559a06'), 'city-state/county': 'Edna Bay, Kasaan, Naukati Bay, Saxman, AK/Ketchikan Gateway', 'city-state': 'Edna Bay, Kasaan, Naukati Bay, Saxman, AK', 'county': 'Ketchikan Gateway'}
# {'_id': ObjectId('5e1aa8bd051df6979a559a07'), 'city-state/county': 'Ketchikan, AK/Wrangell City and', 'city-state': 'Ketchikan, AK', 'county': 'Wrangell City and'}
# {'_id': ObjectId('5e1aa8bd051df6979a559a08'), 'city-state/county': 'Ketchikan, AK/Prince of Wales-Hyder Census Area', 'city-state': 'Ketchikan, AK', 'county': 'Prince of Wales-Hyder Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a559a09'), 'city-state/county': 'Ketchikan, AK/Prince of Wales-Hyder Census Area', 'city-state': 'Ketchikan, AK', 'county': 'Prince of Wales-Hyder Census Area'}
# {'_id': ObjectId('5e1aa8bd051df6979a559a0a'), 'city-state/county': 'Edna Bay, Kasaan, AK/Prince of Wales-Outer Ketchikan', 'city-state': 'Edna Bay, Kasaan, AK', 'county': 'Prince of Wales-Outer Ketchikan'}
