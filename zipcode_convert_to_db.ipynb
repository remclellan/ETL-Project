# %% [markdown]
# # County Source Data
#
# Using Pandas to import csv file of Zipcodes to identify counties associated with cities in the Instacart dataset.
#
# The reason for this is that the Food Desert data is based on county level information and the only way to compare the areas is to utilize the data set and join in MongoDB.

# %% [markdown]
# ### Import dependencies

# %%
import os
import pandas as pd
from pandas import DataFrame
import pymongo

# %% [markdown]
# ### Setup DB connection and establish collection for storage

# %%
# Setup connection to MongoDB
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Create Collection to receive data
db = client.food_desert_db
collection = db.zipcode_county_data

# %% [markdown]
# ### Import and read file

# %%
csv_path = os.path.join('Data', 'zip_code_database.csv')
#zips_df = pd.read_csv(csv_path)
#zips_df.head(10)

# %%
pd.read_csv(csv_path, nrows=1).columns
# Out:
# Index(['zip', 'type', 'decommissioned', 'primary_city', 'acceptable_cities',
#        'unacceptable_cities', 'state', 'county', 'timezone', 'area_codes',
#        'world_region', 'country', 'latitude', 'longitude',
#        'irs_estimated_population_2015'],
#       dtype='object')

# %%
data = pd.read_csv(csv_path)[['primary_city', 'acceptable_cities','state', 'county']]
data.head(10)
# Out:
#   primary_city acceptable_cities state               county
# 0   Holtsville               NaN    NY       Suffolk County
# 1   Holtsville               NaN    NY       Suffolk County
# 2     Adjuntas               NaN    PR   Adjuntas Municipio
# 3       Aguada               NaN    PR     Aguada Municipio
# 4    Aguadilla             Ramey    PR  Aguadilla Municipio
# 5    Aguadilla             Ramey    PR                  NaN
# 6    Aguadilla               NaN    PR                  NaN
# 7      Maricao               NaN    PR    Maricao Municipio
# 8       Anasco               NaN    PR     Anasco Municipio
# 9      Angeles               NaN    PR                  NaN

# %%
data.count()
# Out:
# primary_city         42632
# acceptable_cities     9023
# state                42632
# county               41790
# dtype: int64

# %%
data.loc[data.isnull().any(axis=1)]
# Out:
#         primary_city acceptable_cities state  \
# 0         Holtsville               NaN    NY
# 1         Holtsville               NaN    NY
# 2           Adjuntas               NaN    PR
# 3             Aguada               NaN    PR
# 5          Aguadilla             Ramey    PR
# 6          Aguadilla               NaN    PR
# 7            Maricao               NaN    PR
# 8             Anasco               NaN    PR
# 9            Angeles               NaN    PR
# 10           Arecibo               NaN    PR
# 11           Arecibo               NaN    PR
# 12           Arecibo               NaN    PR
# 13          Bajadero               NaN    PR
# 14       Barceloneta               NaN    PR
# 15          Boqueron               NaN    PR
# 16         Cabo Rojo               NaN    PR
# 17          Penuelas               NaN    PR
# 18             Camuy               NaN    PR
# 20           Rosario               NaN    PR
# 21     Sabana Grande               NaN    PR
# 22            Ciales               NaN    PR
# 23            Utuado               NaN    PR
# 24            Dorado               NaN    PR
# 25          Ensenada               NaN    PR
# 26           Florida               NaN    PR
# 27       Garrochales               NaN    PR
# 28           Guanica               NaN    PR
# 29        Guayanilla               NaN    PR
# 30           Hatillo               NaN    PR
# 31       Hormigueros               NaN    PR
# ...              ...               ...   ...
# 42586         Teller               NaN    AK
# 42587            Tok               NaN    AK
# 42589        Venetie               NaN    AK
# 42590     Wainwright               NaN    AK
# 42591          Wales               NaN    AK
# 42594         Ambler               NaN    AK
# 42597      Fairbanks               NaN    AK
# 42599         Juneau               NaN    AK
# 42600         Juneau               NaN    AK
# 42601         Juneau               NaN    AK
# 42602         Juneau               NaN    AK
# 42603         Juneau               NaN    AK
# 42604         Angoon               NaN    AK
# 42607     Elfin Cove               NaN    AK
# 42608       Gustavus               NaN    AK
# 42609         Haines               NaN    AK
# 42610         Hoonah               NaN    AK
# 42611           Kake               NaN    AK
# 42612        Pelican               NaN    AK
# 42614          Sitka               NaN    AK
# 42616        Skagway               NaN    AK
# 42618         Juneau               NaN    AK
# 42623          Craig               NaN    AK
# 42624       Hydaburg               NaN    AK
# 42625          Hyder               NaN    AK
# 42626        Klawock               NaN    AK
# 42627     Metlakatla               NaN    AK
# 42628    Point Baker               NaN    AK
# 42629      Ward Cove               NaN    AK
# 42630       Wrangell               NaN    AK
#
#                                         county
# 0                               Suffolk County
# 1                               Suffolk County
# 2                           Adjuntas Municipio
# 3                             Aguada Municipio
# 5                                          NaN
# 6                                          NaN
# 7                            Maricao Municipio
# 8                             Anasco Municipio
# 9                                          NaN
# 10                           Arecibo Municipio
# 11                                         NaN
# 12                                         NaN
# 13                           Arecibo Municipio
# 14                       Barceloneta Municipio
# 15                         Cabo Rojo Municipio
# 16                         Cabo Rojo Municipio
# 17                          Penuelas Municipio
# 18                             Camuy Municipio
# 20                                         NaN
# 21                     Sabana Grande Municipio
# 22                            Ciales Municipio
# 23                            Utuado Municipio
# 24                            Dorado Municipio
# 25                           Guanica Municipio
# 26                           Florida Municipio
# 27                           Arecibo Municipio
# 28                           Guanica Municipio
# 29                        Guayanilla Municipio
# 30                           Hatillo Municipio
# 31                       Hormigueros Municipio
# ...                                        ...
# 42586                         Nome Census Area
# 42587          Southeast Fairbanks Census Area
# 42589                Yukon-Koyukuk Census Area
# 42590                      North Slope Borough
# 42591                         Nome Census Area
# 42594                 Northwest Arctic Borough
# 42597                Yukon-Koyukuk Census Area
# 42599                  Juneau City and Borough
# 42600               City and Borough of Juneau
# 42601               City and Borough of Juneau
# 42602               City and Borough of Juneau
# 42603               City and Borough of Juneau
# 42604                Hoonah-Angoon Census Area
# 42607                Hoonah-Angoon Census Area
# 42608                Hoonah-Angoon Census Area
# 42609                           Haines Borough
# 42610                Hoonah-Angoon Census Area
# 42611                   Petersburg Census Area
# 42612                Hoonah-Angoon Census Area
# 42614                   Sitka City and Borough
# 42616                     Skagway Municipality
# 42618               City and Borough of Juneau
# 42623        Prince of Wales-Hyder Census Area
# 42624        Prince of Wales-Hyder Census Area
# 42625        Prince of Wales-Hyder Census Area
# 42626        Prince of Wales-Hyder Census Area
# 42627  Prince of Wales-Outer Ketchikan Borough
# 42628        Prince of Wales-Hyder Census Area
# 42629                Ketchikan Gateway Borough
# 42630                Wrangell City and Borough
#
# [33655 rows x 4 columns]

# %%
data.dropna(subset=['county'], inplace=True)

# %%
data['acceptable_cities'].fillna(data['primary_city'],inplace=True)
data.head()
# Out:
#   primary_city acceptable_cities state               county
# 0   Holtsville        Holtsville    NY       Suffolk County
# 1   Holtsville        Holtsville    NY       Suffolk County
# 2     Adjuntas          Adjuntas    PR   Adjuntas Municipio
# 3       Aguada            Aguada    PR     Aguada Municipio
# 4    Aguadilla             Ramey    PR  Aguadilla Municipio

# %%
data_duplicates_removed = DataFrame.drop_duplicates(data).copy()
data_duplicates_removed.count()
# Out:
# primary_city         32033
# acceptable_cities    32033
# state                32033
# county               32033
# dtype: int64

# %%
data_duplicates_removed.head()
# Out:
#   primary_city acceptable_cities state               county
# 0   Holtsville        Holtsville    NY       Suffolk County
# 2     Adjuntas          Adjuntas    PR   Adjuntas Municipio
# 3       Aguada            Aguada    PR     Aguada Municipio
# 4    Aguadilla             Ramey    PR  Aguadilla Municipio
# 7      Maricao           Maricao    PR    Maricao Municipio

# %% [markdown]
# ### Add column to insert city, state so that it can be used to match up with the instacart data and drop unnecessary columns

# %%
data_duplicates_removed['primary_city-state'] = data_duplicates_removed['primary_city'] +', '+ data_duplicates_removed['state']
data_duplicates_removed['acceptable_city-state'] = data_duplicates_removed['acceptable_cities'] +', '+ data_duplicates_removed['state']
data_duplicates_removed['primary_city-state/county'] = data_duplicates_removed['primary_city'] +', '+ data_duplicates_removed['state'] +'/'+ data_duplicates_removed['county']
data_duplicates_removed['acceptable_city-state/county'] = data_duplicates_removed['acceptable_cities'] +', '+ data_duplicates_removed['state'] +'/'+ data_duplicates_removed['county']
data_duplicates_removed.head(10)
# Out:
#    primary_city acceptable_cities state                 county  \
# 0    Holtsville        Holtsville    NY         Suffolk County
# 2      Adjuntas          Adjuntas    PR     Adjuntas Municipio
# 3        Aguada            Aguada    PR       Aguada Municipio
# 4     Aguadilla             Ramey    PR    Aguadilla Municipio
# 7       Maricao           Maricao    PR      Maricao Municipio
# 8        Anasco            Anasco    PR       Anasco Municipio
# 10      Arecibo           Arecibo    PR      Arecibo Municipio
# 13     Bajadero          Bajadero    PR      Arecibo Municipio
# 14  Barceloneta       Barceloneta    PR  Barceloneta Municipio
# 15     Boqueron          Boqueron    PR    Cabo Rojo Municipio
#
#    primary_city-state acceptable_city-state  \
# 0      Holtsville, NY        Holtsville, NY
# 2        Adjuntas, PR          Adjuntas, PR
# 3          Aguada, PR            Aguada, PR
# 4       Aguadilla, PR             Ramey, PR
# 7         Maricao, PR           Maricao, PR
# 8          Anasco, PR            Anasco, PR
# 10        Arecibo, PR           Arecibo, PR
# 13       Bajadero, PR          Bajadero, PR
# 14    Barceloneta, PR       Barceloneta, PR
# 15       Boqueron, PR          Boqueron, PR
#
#                 primary_city-state/county  \
# 0           Holtsville, NY/Suffolk County
# 2         Adjuntas, PR/Adjuntas Municipio
# 3             Aguada, PR/Aguada Municipio
# 4       Aguadilla, PR/Aguadilla Municipio
# 7           Maricao, PR/Maricao Municipio
# 8             Anasco, PR/Anasco Municipio
# 10          Arecibo, PR/Arecibo Municipio
# 13         Bajadero, PR/Arecibo Municipio
# 14  Barceloneta, PR/Barceloneta Municipio
# 15       Boqueron, PR/Cabo Rojo Municipio
#
#              acceptable_city-state/county
# 0           Holtsville, NY/Suffolk County
# 2         Adjuntas, PR/Adjuntas Municipio
# 3             Aguada, PR/Aguada Municipio
# 4           Ramey, PR/Aguadilla Municipio
# 7           Maricao, PR/Maricao Municipio
# 8             Anasco, PR/Anasco Municipio
# 10          Arecibo, PR/Arecibo Municipio
# 13         Bajadero, PR/Arecibo Municipio
# 14  Barceloneta, PR/Barceloneta Municipio
# 15       Boqueron, PR/Cabo Rojo Municipio

# %%
data_duplicates_removed['primary_city-state/county'].value_counts()
# Out:
# Pittsburgh, PA/Allegheny County              41
# Miami, FL/Miami-Dade County                  35
# Cincinnati, OH/Hamilton County               32
# Los Angeles, CA/Los Angeles County           29
# Louisville, KY/Jefferson County              26
# Fort Lauderdale, FL/Broward County           22
# Saint Louis, MO/St. Louis County             21
# Minneapolis, MN/Hennepin County              20
# Cleveland, OH/Cuyahoga County                20
# Indianapolis, IN/Marion County               19
# Salt Lake City, UT/Salt Lake County          18
# Birmingham, AL/Jefferson County              17
# San Antonio, TX/Bexar County                 17
# San Juan, PR/San Juan Municipio              17
# New York, NY/New York County                 16
# Orlando, FL/Orange County                    15
# Buffalo, NY/Erie County                      15
# Fort Worth, TX/Tarrant County                15
# Tampa, FL/Hillsborough County                15
# Milwaukee, WI/Milwaukee County               14
# Dayton, OH/Montgomery County                 14
# Saint Petersburg, FL/Pinellas County         13
# Atlanta, GA/Fulton County                    13
# Seattle, WA/King County                      13
# Baltimore, MD/Baltimore city                 12
# Saint Paul, MN/Ramsey County                 11
# West Palm Beach, FL/Palm Beach County        11
# Columbus, OH/Franklin County                 10
# Pompano Beach, FL/Broward County             10
# Oklahoma City, OK/Oklahoma County            10
#                                              ..
# North Hampton, NH/Rockingham County           1
# West Boothbay Harbor, ME/Lincoln County       1
# Caruthersville, MO/Pemiscot County            1
# North Jay, ME/Franklin County                 1
# North Branch, MN/Chisago County               1
# Shamokin, PA/Northumberland County            1
# Glasco, NY/Ulster County                      1
# Auxvasse, MO/Callaway County                  1
# Colcord, OK/Delaware County                   1
# Glengary, WV/Berkeley County                  1
# Wachapreague, VA/Accomack County              1
# Issaquah, WA/King County                      1
# Thomaston, CT/Litchfield County               1
# Amboy, IL/Lee County                          1
# Lake Saint Louis, MO/St. Charles County       1
# Akron, IA/Plymouth County                     1
# New Iberia, LA/Iberia Parish                  1
# Milton Mills, NH/Strafford County             1
# Kalkaska, MI/Kalkaska County                  1
# Wacissa, FL/Jefferson County                  1
# Bastian, VA/Bland County                      1
# Trussville, AL/Jefferson County               1
# Woodinville, WA/King County                   1
# Coahoma, TX/Howard County                     1
# Baraboo, WI/Sauk County                       1
# Eads, CO/Kiowa County                         1
# Fombell, PA/Beaver County                     1
# Tappen, ND/Kidder County                      1
# Antelope, MT/Sheridan County                  1
# Port Jefferson Station, NY/Suffolk County     1
# Name: primary_city-state/county, Length: 29967, dtype: int64

# %%
data_duplicates_removed['acceptable_city-state/county'].value_counts()
# Out:
# Flushing, NY/Queens County                                              12
# Boston, MA/Suffolk County                                               11
# Baltimore, MD/Baltimore County                                          11
# Jamaica, NY/Queens County                                               10
# Cleveland, OH/Cuyahoga County                                           10
# Detroit, MI/Wayne County                                                 7
# Richmond, RI/Washington County                                           6
# Gallup, NM/McKinley County                                               6
# Fairbanks, AK/Fairbanks North Star Borough                               5
# Kingman, AZ/Mohave County                                                5
# West Deptford, NJ/Gloucester County                                      5
# Chinle, AZ/Apache County                                                 5
# Flagstaff, AZ/Coconino County                                            5
# Severance, CO/Weld County                                                4
# Red Bank, NJ/Monmouth County                                             4
# Silver City, NM/Grant County                                             4
# Des Moines, IA/Polk County                                               4
# Bethel, AK/Bethel Census Area                                            4
# New Haven, CT/New Haven County                                           4
# Van Nuys, CA/Los Angeles County                                          4
# Hartford, CT/Hartford County                                             4
# Barrow, AK/North Slope Borough                                           4
# Santa Clarita, CA/Los Angeles County                                     4
# Norristown, PA/Montgomery County                                         4
# Las Vegas, NV/Clark County                                               4
# Miami, FL/Miami-Dade County                                              4
# Scranton, PA/Lackawanna County                                           4
# Los Angeles, CA/Los Angeles County                                       4
# Shawnee Mission, Shawnee Msn, KS/Johnson County                          4
# Lake Wales, FL/Polk County                                               3
#                                                                         ..
# Regan, ND/Burleigh County                                                1
# Staples, TX/Guadalupe County                                             1
# North River, Reiles Acres, ND/Cass County                                1
# Arcadia, OH/Hancock County                                               1
# Windber, PA/Somerset County                                              1
# Schley, VA/Gloucester County                                             1
# Montpelier, VA/Hanover County                                            1
# Frontenac, Grenell, Murray Isle, NY/Jefferson County                     1
# Oakalla, TX/Burnet County                                                1
# Barnesville, NC/Robeson County                                           1
# Maryville, IL/Madison County                                             1
# Hydaburg, AK/Prince of Wales-Hyder Census Area                           1
# Dogue, VA/King George County                                             1
# Amber, OK/Grady County                                                   1
# Chenoa, IL/McLean County                                                 1
# Holbrook, ID/Oneida County                                               1
# Eldorado Afs, TX/Schleicher County                                       1
# Bloxom, VA/Accomack County                                               1
# The Woodlands, TX/Montgomery County                                      1
# Greenwood, FL/Jackson County                                             1
# Cape San Blas, Mexico Beach, Overstreet, Port St Joe, FL/Gulf County     1
# El Lago, Taylor Lake Village, Taylor Lk Vlg, TX/Harris County            1
# Harford, NY/Cortland County                                              1
# W Boothbay Ha, W Boothbay Harbor, W Boothby Hbr, ME/Lincoln County       1
# Imnaha, OR/Wallowa County                                                1
# Pinon, AZ/Apache County                                                  1
# Yorba Linda, CA/Orange County                                            1
# Unionville, TN/Bedford County                                            1
# Landgrove, VT/Windham County                                             1
# Mannboro, VA/Amelia County                                               1
# Name: acceptable_city-state/county, Length: 31247, dtype: int64

# %%
primary_cities = data_duplicates_removed[['primary_city-state/county']]
primary_cities.rename(columns = {'primary_city-state/county': 'city-state/county'}, 
                                 inplace = True) 
primary_cities.head()
# Out:
#                    city-state/county
# 0      Holtsville, NY/Suffolk County
# 2    Adjuntas, PR/Adjuntas Municipio
# 3        Aguada, PR/Aguada Municipio
# 4  Aguadilla, PR/Aguadilla Municipio
# 7      Maricao, PR/Maricao Municipio

# %%
acceptable_cities = data_duplicates_removed[['acceptable_city-state/county']]
acceptable_cities.rename(columns = {'acceptable_city-state/county': 'city-state/county'}, 
                                 inplace = True) 
acceptable_cities.head()
# Out:
#                  city-state/county
# 0    Holtsville, NY/Suffolk County
# 2  Adjuntas, PR/Adjuntas Municipio
# 3      Aguada, PR/Aguada Municipio
# 4    Ramey, PR/Aguadilla Municipio
# 7    Maricao, PR/Maricao Municipio

# %%
all_cities = pd.merge(primary_cities, acceptable_cities, on='city-state/county', how='outer')
all_cities.head()
# Out:
#                    city-state/county
# 0      Holtsville, NY/Suffolk County
# 1    Adjuntas, PR/Adjuntas Municipio
# 2        Aguada, PR/Aguada Municipio
# 3  Aguadilla, PR/Aguadilla Municipio
# 4      Maricao, PR/Maricao Municipio

# %%
all_cities.count()
# Out:
# city-state/county    40652
# dtype: int64

# %%
all_cities[['city-state','county']] = all_cities['city-state/county'].str.split('/', n=1, expand=True)
all_cities.head()
# Out:
#                    city-state/county      city-state               county
# 0      Holtsville, NY/Suffolk County  Holtsville, NY       Suffolk County
# 1    Adjuntas, PR/Adjuntas Municipio    Adjuntas, PR   Adjuntas Municipio
# 2        Aguada, PR/Aguada Municipio      Aguada, PR     Aguada Municipio
# 3  Aguadilla, PR/Aguadilla Municipio   Aguadilla, PR  Aguadilla Municipio
# 4      Maricao, PR/Maricao Municipio     Maricao, PR    Maricao Municipio

# %%
collection.insert_many(all_cities.to_dict('records'))

# %%
listings = db.zipcode_county_data.find()

for listing in listings:
    print(listing)
# Out:
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b253'), 'city-state/county': 'Holtsville, NY/Suffolk County', 'city-state': 'Holtsville, NY', 'county': 'Suffolk County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b254'), 'city-state/county': 'Adjuntas, PR/Adjuntas Municipio', 'city-state': 'Adjuntas, PR', 'county': 'Adjuntas Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b255'), 'city-state/county': 'Aguada, PR/Aguada Municipio', 'city-state': 'Aguada, PR', 'county': 'Aguada Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b256'), 'city-state/county': 'Aguadilla, PR/Aguadilla Municipio', 'city-state': 'Aguadilla, PR', 'county': 'Aguadilla Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b257'), 'city-state/county': 'Maricao, PR/Maricao Municipio', 'city-state': 'Maricao, PR', 'county': 'Maricao Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b258'), 'city-state/county': 'Anasco, PR/Anasco Municipio', 'city-state': 'Anasco, PR', 'county': 'Anasco Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b259'), 'city-state/county': 'Arecibo, PR/Arecibo Municipio', 'city-state': 'Arecibo, PR', 'county': 'Arecibo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b25a'), 'city-state/county': 'Bajadero, PR/Arecibo Municipio', 'city-state': 'Bajadero, PR', 'county': 'Arecibo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b25b'), 'city-state/county': 'Barceloneta, PR/Barceloneta Municipio', 'city-state': 'Barceloneta, PR', 'county': 'Barceloneta Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b25c'), 'city-state/county': 'Boqueron, PR/Cabo Rojo Municipio', 'city-state': 'Boqueron, PR', 'county': 'Cabo Rojo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b25d'), 'city-state/county': 'Cabo Rojo, PR/Cabo Rojo Municipio', 'city-state': 'Cabo Rojo, PR', 'county': 'Cabo Rojo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b25e'), 'city-state/county': 'Penuelas, PR/Penuelas Municipio', 'city-state': 'Penuelas, PR', 'county': 'Penuelas Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b25f'), 'city-state/county': 'Camuy, PR/Camuy Municipio', 'city-state': 'Camuy, PR', 'county': 'Camuy Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b260'), 'city-state/county': 'Castaner, PR/Lares Municipio', 'city-state': 'Castaner, PR', 'county': 'Lares Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b261'), 'city-state/county': 'Sabana Grande, PR/Sabana Grande Municipio', 'city-state': 'Sabana Grande, PR', 'county': 'Sabana Grande Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b262'), 'city-state/county': 'Ciales, PR/Ciales Municipio', 'city-state': 'Ciales, PR', 'county': 'Ciales Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b263'), 'city-state/county': 'Utuado, PR/Utuado Municipio', 'city-state': 'Utuado, PR', 'county': 'Utuado Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b264'), 'city-state/county': 'Dorado, PR/Dorado Municipio', 'city-state': 'Dorado, PR', 'county': 'Dorado Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b265'), 'city-state/county': 'Ensenada, PR/Guanica Municipio', 'city-state': 'Ensenada, PR', 'county': 'Guanica Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b266'), 'city-state/county': 'Florida, PR/Florida Municipio', 'city-state': 'Florida, PR', 'county': 'Florida Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b267'), 'city-state/county': 'Garrochales, PR/Arecibo Municipio', 'city-state': 'Garrochales, PR', 'county': 'Arecibo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b268'), 'city-state/county': 'Guanica, PR/Guanica Municipio', 'city-state': 'Guanica, PR', 'county': 'Guanica Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b269'), 'city-state/county': 'Guayanilla, PR/Guayanilla Municipio', 'city-state': 'Guayanilla, PR', 'county': 'Guayanilla Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b26a'), 'city-state/county': 'Hatillo, PR/Hatillo Municipio', 'city-state': 'Hatillo, PR', 'county': 'Hatillo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b26b'), 'city-state/county': 'Hormigueros, PR/Hormigueros Municipio', 'city-state': 'Hormigueros, PR', 'county': 'Hormigueros Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b26c'), 'city-state/county': 'Isabela, PR/Isabela Municipio', 'city-state': 'Isabela, PR', 'county': 'Isabela Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b26d'), 'city-state/county': 'Jayuya, PR/Jayuya Municipio', 'city-state': 'Jayuya, PR', 'county': 'Jayuya Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b26e'), 'city-state/county': 'Lajas, PR/Lajas Municipio', 'city-state': 'Lajas, PR', 'county': 'Lajas Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b26f'), 'city-state/county': 'Lares, PR/Lares Municipio', 'city-state': 'Lares, PR', 'county': 'Lares Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b270'), 'city-state/county': 'Las Marias, PR/Las Marias Municipio', 'city-state': 'Las Marias, PR', 'county': 'Las Marias Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b271'), 'city-state/county': 'Manati, PR/Manati Municipio', 'city-state': 'Manati, PR', 'county': 'Manati Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b272'), 'city-state/county': 'Moca, PR/Moca Municipio', 'city-state': 'Moca, PR', 'county': 'Moca Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b273'), 'city-state/county': 'Rincon, PR/Rincon Municipio', 'city-state': 'Rincon, PR', 'county': 'Rincon Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b274'), 'city-state/county': 'Quebradillas, PR/Quebradillas Municipio', 'city-state': 'Quebradillas, PR', 'county': 'Quebradillas Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b275'), 'city-state/county': 'Mayaguez, PR/Mayaguez Municipio', 'city-state': 'Mayaguez, PR', 'county': 'Mayaguez Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b276'), 'city-state/county': 'San German, PR/San German Municipio', 'city-state': 'San German, PR', 'county': 'San German Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b277'), 'city-state/county': 'San Sebastian, PR/San Sebastian Municipio', 'city-state': 'San Sebastian, PR', 'county': 'San Sebastian Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b278'), 'city-state/county': 'Morovis, PR/Morovis Municipio', 'city-state': 'Morovis, PR', 'county': 'Morovis Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b279'), 'city-state/county': 'Sabana Hoyos, PR/Arecibo Municipio', 'city-state': 'Sabana Hoyos, PR', 'county': 'Arecibo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b27a'), 'city-state/county': 'San Antonio, PR/Aguadilla Municipio', 'city-state': 'San Antonio, PR', 'county': 'Aguadilla Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b27b'), 'city-state/county': 'Vega Alta, PR/Vega Alta Municipio', 'city-state': 'Vega Alta, PR', 'county': 'Vega Alta Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b27c'), 'city-state/county': 'Vega Baja, PR/Vega Baja Municipio', 'city-state': 'Vega Baja, PR', 'county': 'Vega Baja Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b27d'), 'city-state/county': 'Yauco, PR/Yauco Municipio', 'city-state': 'Yauco, PR', 'county': 'Yauco Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b27e'), 'city-state/county': 'Aguas Buenas, PR/Aguas Buenas Municipio', 'city-state': 'Aguas Buenas, PR', 'county': 'Aguas Buenas Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b27f'), 'city-state/county': 'Aguirre, PR/Salinas Municipio', 'city-state': 'Aguirre, PR', 'county': 'Salinas Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b280'), 'city-state/county': 'Aibonito, PR/Aibonito Municipio', 'city-state': 'Aibonito, PR', 'county': 'Aibonito Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b281'), 'city-state/county': 'Maunabo, PR/Maunabo Municipio', 'city-state': 'Maunabo, PR', 'county': 'Maunabo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b282'), 'city-state/county': 'Arroyo, PR/Arroyo Municipio', 'city-state': 'Arroyo, PR', 'county': 'Arroyo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b283'), 'city-state/county': 'Mercedita, PR/Ponce Municipio', 'city-state': 'Mercedita, PR', 'county': 'Ponce Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b284'), 'city-state/county': 'Ponce, PR/Ponce Municipio', 'city-state': 'Ponce, PR', 'county': 'Ponce Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b285'), 'city-state/county': 'Ponce, PR/Ponce Municipio', 'city-state': 'Ponce, PR', 'county': 'Ponce Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b286'), 'city-state/county': 'Ponce, PR/Ponce Municipio', 'city-state': 'Ponce, PR', 'county': 'Ponce Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b287'), 'city-state/county': 'Ponce, PR/Ponce Municipio', 'city-state': 'Ponce, PR', 'county': 'Ponce Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b288'), 'city-state/county': 'Ponce, PR/Ponce Municipio', 'city-state': 'Ponce, PR', 'county': 'Ponce Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b289'), 'city-state/county': 'Ponce, PR/Ponce Municipio', 'city-state': 'Ponce, PR', 'county': 'Ponce Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b28a'), 'city-state/county': 'Naguabo, PR/Naguabo Municipio', 'city-state': 'Naguabo, PR', 'county': 'Naguabo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b28b'), 'city-state/county': 'Naranjito, PR/Naranjito Municipio', 'city-state': 'Naranjito, PR', 'county': 'Naranjito Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b28c'), 'city-state/county': 'Orocovis, PR/Orocovis Municipio', 'city-state': 'Orocovis, PR', 'county': 'Orocovis Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b28d'), 'city-state/county': 'Patillas, PR/Patillas Municipio', 'city-state': 'Patillas, PR', 'county': 'Patillas Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b28e'), 'city-state/county': 'Caguas, PR/Caguas Municipio', 'city-state': 'Caguas, PR', 'county': 'Caguas Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b28f'), 'city-state/county': 'Canovanas, PR/Canovanas Municipio', 'city-state': 'Canovanas, PR', 'county': 'Canovanas Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b290'), 'city-state/county': 'Ceiba, PR/Ceiba Municipio', 'city-state': 'Ceiba, PR', 'county': 'Ceiba Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b291'), 'city-state/county': 'Cayey, PR/Cayey Municipio', 'city-state': 'Cayey, PR', 'county': 'Cayey Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b292'), 'city-state/county': 'Fajardo, PR/Fajardo Municipio', 'city-state': 'Fajardo, PR', 'county': 'Fajardo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b293'), 'city-state/county': 'Cidra, PR/Cidra Municipio', 'city-state': 'Cidra, PR', 'county': 'Cidra Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b294'), 'city-state/county': 'Puerto Real, PR/Fajardo Municipio', 'city-state': 'Puerto Real, PR', 'county': 'Fajardo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b295'), 'city-state/county': 'Punta Santiago, PR/Humacao Municipio', 'city-state': 'Punta Santiago, PR', 'county': 'Humacao Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b296'), 'city-state/county': 'Rio Grande, PR/Rio Grande Municipio', 'city-state': 'Rio Grande, PR', 'county': 'Rio Grande Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b297'), 'city-state/county': 'Salinas, PR/Salinas Municipio', 'city-state': 'Salinas, PR', 'county': 'Salinas Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b298'), 'city-state/county': 'San Lorenzo, PR/San Lorenzo Municipio', 'city-state': 'San Lorenzo, PR', 'county': 'San Lorenzo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b299'), 'city-state/county': 'Santa Isabel, PR/Santa Isabel Municipio', 'city-state': 'Santa Isabel, PR', 'county': 'Santa Isabel Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b29a'), 'city-state/county': 'Vieques, PR/Vieques Municipio', 'city-state': 'Vieques, PR', 'county': 'Vieques Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b29b'), 'city-state/county': 'Villalba, PR/Villalba Municipio', 'city-state': 'Villalba, PR', 'county': 'Villalba Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b29c'), 'city-state/county': 'Yabucoa, PR/Yabucoa Municipio', 'city-state': 'Yabucoa, PR', 'county': 'Yabucoa Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b29d'), 'city-state/county': 'Coamo, PR/Coamo Municipio', 'city-state': 'Coamo, PR', 'county': 'Coamo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b29e'), 'city-state/county': 'Las Piedras, PR/Las Piedras Municipio', 'city-state': 'Las Piedras, PR', 'county': 'Las Piedras Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b29f'), 'city-state/county': 'Loiza, PR/Loiza Municipio', 'city-state': 'Loiza, PR', 'county': 'Loiza Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2a0'), 'city-state/county': 'Luquillo, PR/Luquillo Municipio', 'city-state': 'Luquillo, PR', 'county': 'Luquillo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2a1'), 'city-state/county': 'Culebra, PR/Culebra Municipio', 'city-state': 'Culebra, PR', 'county': 'Culebra Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2a2'), 'city-state/county': 'Juncos, PR/Juncos Municipio', 'city-state': 'Juncos, PR', 'county': 'Juncos Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2a3'), 'city-state/county': 'Gurabo, PR/Gurabo Municipio', 'city-state': 'Gurabo, PR', 'county': 'Gurabo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2a4'), 'city-state/county': 'Coto Laurel, PR/Ponce Municipio', 'city-state': 'Coto Laurel, PR', 'county': 'Ponce Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2a5'), 'city-state/county': 'Comerio, PR/Comerio Municipio', 'city-state': 'Comerio, PR', 'county': 'Comerio Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2a6'), 'city-state/county': 'Corozal, PR/Corozal Municipio', 'city-state': 'Corozal, PR', 'county': 'Corozal Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2a7'), 'city-state/county': 'Guayama, PR/Guayama Municipio', 'city-state': 'Guayama, PR', 'county': 'Guayama Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2a8'), 'city-state/county': 'La Plata, PR/Aibonito Municipio', 'city-state': 'La Plata, PR', 'county': 'Aibonito Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2a9'), 'city-state/county': 'Humacao, PR/Humacao Municipio', 'city-state': 'Humacao, PR', 'county': 'Humacao Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2aa'), 'city-state/county': 'Barranquitas, PR/Barranquitas Municipio', 'city-state': 'Barranquitas, PR', 'county': 'Barranquitas Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2ab'), 'city-state/county': 'Juana Diaz, PR/Juana Diaz Municipio', 'city-state': 'Juana Diaz, PR', 'county': 'Juana Diaz Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2ac'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2ad'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2ae'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2af'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2b0'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2b1'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2b2'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2b3'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2b4'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2b5'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2b6'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2b7'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2b8'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2b9'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2ba'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2bb'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2bc'), 'city-state/county': 'San Juan, PR/San Juan Municipio', 'city-state': 'San Juan, PR', 'county': 'San Juan Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2bd'), 'city-state/county': 'San Juan, PR/San Juan', 'city-state': 'San Juan, PR', 'county': 'San Juan'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2be'), 'city-state/county': 'San Juan, PR/San Juan', 'city-state': 'San Juan, PR', 'county': 'San Juan'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2bf'), 'city-state/county': 'San Juan, PR/San Juan', 'city-state': 'San Juan, PR', 'county': 'San Juan'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2c0'), 'city-state/county': 'Fort Buchanan, PR/Guaynabo Municipio', 'city-state': 'Fort Buchanan, PR', 'county': 'Guaynabo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2c1'), 'city-state/county': 'Toa Baja, PR/Toa Baja Municipio', 'city-state': 'Toa Baja, PR', 'county': 'Toa Baja Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2c2'), 'city-state/county': 'Toa Baja, PR/Toa Baja Municipio', 'city-state': 'Toa Baja, PR', 'county': 'Toa Baja Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2c3'), 'city-state/county': 'Toa Baja, PR/Dorado Municipio', 'city-state': 'Toa Baja, PR', 'county': 'Dorado Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2c4'), 'city-state/county': 'Sabana Seca, PR/Toa Baja Municipio', 'city-state': 'Sabana Seca, PR', 'county': 'Toa Baja Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2c5'), 'city-state/county': 'Toa Alta, PR/Toa Alta Municipio', 'city-state': 'Toa Alta, PR', 'county': 'Toa Alta Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2c6'), 'city-state/county': 'Toa Alta, PR/Toa Alta', 'city-state': 'Toa Alta, PR', 'county': 'Toa Alta'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2c7'), 'city-state/county': 'Bayamon, PR/Bayamon Municipio', 'city-state': 'Bayamon, PR', 'county': 'Bayamon Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2c8'), 'city-state/county': 'Bayamon, PR/Bayamon', 'city-state': 'Bayamon, PR', 'county': 'Bayamon'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2c9'), 'city-state/county': 'Catano, PR/Catano Municipio', 'city-state': 'Catano, PR', 'county': 'Catano Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2ca'), 'city-state/county': 'Catano, PR/Catano', 'city-state': 'Catano, PR', 'county': 'Catano'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2cb'), 'city-state/county': 'Guaynabo, PR/Guaynabo Municipio', 'city-state': 'Guaynabo, PR', 'county': 'Guaynabo Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2cc'), 'city-state/county': 'Trujillo Alto, PR/Trujillo Alto Municipio', 'city-state': 'Trujillo Alto, PR', 'county': 'Trujillo Alto Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2cd'), 'city-state/county': 'Saint Just, PR/San Juan', 'city-state': 'Saint Just, PR', 'county': 'San Juan'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2ce'), 'city-state/county': 'Carolina, PR/Carolina Municipio', 'city-state': 'Carolina, PR', 'county': 'Carolina Municipio'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2cf'), 'city-state/county': 'Carolina, PR/Carolina', 'city-state': 'Carolina, PR', 'county': 'Carolina'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2d0'), 'city-state/county': 'Agawam, MA/Hampden County', 'city-state': 'Agawam, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2d1'), 'city-state/county': 'Amherst, MA/Hampshire County', 'city-state': 'Amherst, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2d2'), 'city-state/county': 'Amherst, MA/Hampshire County', 'city-state': 'Amherst, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2d3'), 'city-state/county': 'Amherst, MA/Hampshire County', 'city-state': 'Amherst, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2d4'), 'city-state/county': 'Amherst, MA/Hampshire County', 'city-state': 'Amherst, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2d5'), 'city-state/county': 'Barre, MA/Worcester County', 'city-state': 'Barre, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2d6'), 'city-state/county': 'Belchertown, MA/Hampshire County', 'city-state': 'Belchertown, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2d7'), 'city-state/county': 'Blandford, MA/Hampden County', 'city-state': 'Blandford, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2d8'), 'city-state/county': 'Bondsville, MA/Hampden County', 'city-state': 'Bondsville, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2d9'), 'city-state/county': 'Brimfield, MA/Hampden County', 'city-state': 'Brimfield, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2da'), 'city-state/county': 'Chester, MA/Hampden County', 'city-state': 'Chester, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2db'), 'city-state/county': 'Chesterfield, MA/Hampshire County', 'city-state': 'Chesterfield, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2dc'), 'city-state/county': 'Chicopee, MA/Hampden County', 'city-state': 'Chicopee, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2dd'), 'city-state/county': 'Chicopee, MA/Hampden County', 'city-state': 'Chicopee, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2de'), 'city-state/county': 'Chicopee, MA/Hampden County', 'city-state': 'Chicopee, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2df'), 'city-state/county': 'Cummington, MA/Hampshire County', 'city-state': 'Cummington, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2e0'), 'city-state/county': 'Easthampton, MA/Hampshire County', 'city-state': 'Easthampton, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2e1'), 'city-state/county': 'East Longmeadow, MA/Hampden County', 'city-state': 'East Longmeadow, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2e2'), 'city-state/county': 'East Otis, MA/Berkshire County', 'city-state': 'East Otis, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2e3'), 'city-state/county': 'Feeding Hills, MA/Hampden County', 'city-state': 'Feeding Hills, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2e4'), 'city-state/county': 'Gilbertville, MA/Worcester County', 'city-state': 'Gilbertville, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2e5'), 'city-state/county': 'Goshen, MA/Hampshire County', 'city-state': 'Goshen, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2e6'), 'city-state/county': 'Granby, MA/Hampshire County', 'city-state': 'Granby, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2e7'), 'city-state/county': 'Granville, MA/Hampden County', 'city-state': 'Granville, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2e8'), 'city-state/county': 'Hadley, MA/Hampshire County', 'city-state': 'Hadley, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2e9'), 'city-state/county': 'Hampden, MA/Hampden County', 'city-state': 'Hampden, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2ea'), 'city-state/county': 'Hardwick, MA/Worcester County', 'city-state': 'Hardwick, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2eb'), 'city-state/county': 'Hatfield, MA/Hampshire County', 'city-state': 'Hatfield, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2ec'), 'city-state/county': 'Haydenville, MA/Hampshire County', 'city-state': 'Haydenville, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2ed'), 'city-state/county': 'Holyoke, MA/Hampden County', 'city-state': 'Holyoke, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2ee'), 'city-state/county': 'Huntington, MA/Hampshire County', 'city-state': 'Huntington, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2ef'), 'city-state/county': 'Leeds, MA/Hampshire County', 'city-state': 'Leeds, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2f0'), 'city-state/county': 'Leverett, MA/Franklin County', 'city-state': 'Leverett, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2f1'), 'city-state/county': 'Ludlow, MA/Hampden County', 'city-state': 'Ludlow, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2f2'), 'city-state/county': 'Monson, MA/Hampden County', 'city-state': 'Monson, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2f3'), 'city-state/county': 'North Amherst, MA/Hampshire County', 'city-state': 'North Amherst, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2f4'), 'city-state/county': 'Northampton, MA/Hampshire County', 'city-state': 'Northampton, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2f5'), 'city-state/county': 'Florence, MA/Hampshire County', 'city-state': 'Florence, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2f6'), 'city-state/county': 'North Hatfield, MA/Hampshire County', 'city-state': 'North Hatfield, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2f7'), 'city-state/county': 'Oakham, MA/Worcester County', 'city-state': 'Oakham, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2f8'), 'city-state/county': 'Palmer, MA/Hampden County', 'city-state': 'Palmer, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2f9'), 'city-state/county': 'Plainfield, MA/Hampshire County', 'city-state': 'Plainfield, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2fa'), 'city-state/county': 'Russell, MA/Hampden County', 'city-state': 'Russell, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2fb'), 'city-state/county': 'Shutesbury, MA/Franklin County', 'city-state': 'Shutesbury, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2fc'), 'city-state/county': 'Southampton, MA/Hampshire County', 'city-state': 'Southampton, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2fd'), 'city-state/county': 'South Barre, MA/Worcester County', 'city-state': 'South Barre, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2fe'), 'city-state/county': 'South Hadley, MA/Hampshire County', 'city-state': 'South Hadley, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b2ff'), 'city-state/county': 'Southwick, MA/Hampden County', 'city-state': 'Southwick, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b300'), 'city-state/county': 'Thorndike, MA/Hampden County', 'city-state': 'Thorndike, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b301'), 'city-state/county': 'Three Rivers, MA/Hampden County', 'city-state': 'Three Rivers, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b302'), 'city-state/county': 'Wales, MA/Hampden County', 'city-state': 'Wales, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b303'), 'city-state/county': 'Ware, MA/Hampshire County', 'city-state': 'Ware, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b304'), 'city-state/county': 'Warren, MA/Worcester County', 'city-state': 'Warren, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b305'), 'city-state/county': 'West Chesterfield, MA/Hampshire County', 'city-state': 'West Chesterfield, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b306'), 'city-state/county': 'Westfield, MA/Hampden County', 'city-state': 'Westfield, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b307'), 'city-state/county': 'Westfield, MA/Hampden County', 'city-state': 'Westfield, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b308'), 'city-state/county': 'West Hatfield, MA/Hampshire County', 'city-state': 'West Hatfield, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b309'), 'city-state/county': 'West Springfield, MA/Hampden County', 'city-state': 'West Springfield, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b30a'), 'city-state/county': 'West Warren, MA/Worcester County', 'city-state': 'West Warren, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b30b'), 'city-state/county': 'Whately, MA/Franklin County', 'city-state': 'Whately, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b30c'), 'city-state/county': 'Wheelwright, MA/Worcester County', 'city-state': 'Wheelwright, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b30d'), 'city-state/county': 'Wilbraham, MA/Hampden County', 'city-state': 'Wilbraham, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b30e'), 'city-state/county': 'Williamsburg, MA/Hampshire County', 'city-state': 'Williamsburg, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b30f'), 'city-state/county': 'Woronoco, MA/Hampden County', 'city-state': 'Woronoco, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b310'), 'city-state/county': 'Worthington, MA/Hampshire County', 'city-state': 'Worthington, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b311'), 'city-state/county': 'Springfield, MA/Hampden County', 'city-state': 'Springfield, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b312'), 'city-state/county': 'Springfield, MA/Hampden County', 'city-state': 'Springfield, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b313'), 'city-state/county': 'Longmeadow, MA/Hampden County', 'city-state': 'Longmeadow, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b314'), 'city-state/county': 'Longmeadow, MA/Hampden County', 'city-state': 'Longmeadow, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b315'), 'city-state/county': 'Indian Orchard, MA/Hampden County', 'city-state': 'Indian Orchard, MA', 'county': 'Hampden County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b316'), 'city-state/county': 'Pittsfield, MA/Berkshire County', 'city-state': 'Pittsfield, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b317'), 'city-state/county': 'Adams, MA/Berkshire County', 'city-state': 'Adams, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b318'), 'city-state/county': 'Ashley Falls, MA/Berkshire County', 'city-state': 'Ashley Falls, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b319'), 'city-state/county': 'Becket, MA/Berkshire County', 'city-state': 'Becket, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b31a'), 'city-state/county': 'Berkshire, MA/Berkshire County', 'city-state': 'Berkshire, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b31b'), 'city-state/county': 'Cheshire, MA/Berkshire County', 'city-state': 'Cheshire, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b31c'), 'city-state/county': 'Dalton, MA/Berkshire County', 'city-state': 'Dalton, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b31d'), 'city-state/county': 'Glendale, MA/Berkshire County', 'city-state': 'Glendale, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b31e'), 'city-state/county': 'Great Barrington, MA/Berkshire County', 'city-state': 'Great Barrington, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b31f'), 'city-state/county': 'Hinsdale, MA/Berkshire County', 'city-state': 'Hinsdale, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b320'), 'city-state/county': 'Housatonic, MA/Berkshire County', 'city-state': 'Housatonic, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b321'), 'city-state/county': 'Lanesboro, MA/Berkshire County', 'city-state': 'Lanesboro, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b322'), 'city-state/county': 'Lee, MA/Berkshire County', 'city-state': 'Lee, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b323'), 'city-state/county': 'Lee, MA/Berkshire County', 'city-state': 'Lee, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b324'), 'city-state/county': 'Lenox, MA/Berkshire County', 'city-state': 'Lenox, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b325'), 'city-state/county': 'Lenox Dale, MA/Berkshire County', 'city-state': 'Lenox Dale, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b326'), 'city-state/county': 'Middlefield, MA/Hampshire County', 'city-state': 'Middlefield, MA', 'county': 'Hampshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b327'), 'city-state/county': 'Mill River, MA/Berkshire County', 'city-state': 'Mill River, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b328'), 'city-state/county': 'Monterey, MA/Berkshire County', 'city-state': 'Monterey, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b329'), 'city-state/county': 'North Adams, MA/Berkshire County', 'city-state': 'North Adams, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b32a'), 'city-state/county': 'North Egremont, MA/Berkshire County', 'city-state': 'North Egremont, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b32b'), 'city-state/county': 'Otis, MA/Berkshire County', 'city-state': 'Otis, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b32c'), 'city-state/county': 'Richmond, MA/Berkshire County', 'city-state': 'Richmond, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b32d'), 'city-state/county': 'Sandisfield, MA/Berkshire County', 'city-state': 'Sandisfield, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b32e'), 'city-state/county': 'Savoy, MA/Berkshire County', 'city-state': 'Savoy, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b32f'), 'city-state/county': 'Sheffield, MA/Berkshire County', 'city-state': 'Sheffield, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b330'), 'city-state/county': 'South Egremont, MA/Berkshire County', 'city-state': 'South Egremont, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b331'), 'city-state/county': 'Southfield, MA/Berkshire County', 'city-state': 'Southfield, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b332'), 'city-state/county': 'South Lee, MA/Berkshire County', 'city-state': 'South Lee, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b333'), 'city-state/county': 'Stockbridge, MA/Berkshire County', 'city-state': 'Stockbridge, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b334'), 'city-state/county': 'Tyringham, MA/Berkshire County', 'city-state': 'Tyringham, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b335'), 'city-state/county': 'West Stockbridge, MA/Berkshire County', 'city-state': 'West Stockbridge, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b336'), 'city-state/county': 'Williamstown, MA/Berkshire County', 'city-state': 'Williamstown, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b337'), 'city-state/county': 'Windsor, MA/Berkshire County', 'city-state': 'Windsor, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b338'), 'city-state/county': 'Greenfield, MA/Franklin County', 'city-state': 'Greenfield, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b339'), 'city-state/county': 'Greenfield, MA/Franklin County', 'city-state': 'Greenfield, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b33a'), 'city-state/county': 'Ashfield, MA/Franklin County', 'city-state': 'Ashfield, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b33b'), 'city-state/county': 'Athol, MA/Worcester County', 'city-state': 'Athol, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b33c'), 'city-state/county': 'Bernardston, MA/Franklin County', 'city-state': 'Bernardston, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b33d'), 'city-state/county': 'Buckland, MA/Franklin County', 'city-state': 'Buckland, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b33e'), 'city-state/county': 'Charlemont, MA/Franklin County', 'city-state': 'Charlemont, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b33f'), 'city-state/county': 'Colrain, MA/Franklin County', 'city-state': 'Colrain, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b340'), 'city-state/county': 'Conway, MA/Franklin County', 'city-state': 'Conway, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b341'), 'city-state/county': 'Deerfield, MA/Franklin County', 'city-state': 'Deerfield, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b342'), 'city-state/county': 'Drury, MA/Berkshire County', 'city-state': 'Drury, MA', 'county': 'Berkshire County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b343'), 'city-state/county': 'Erving, MA/Franklin County', 'city-state': 'Erving, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b344'), 'city-state/county': 'Heath, MA/Franklin County', 'city-state': 'Heath, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b345'), 'city-state/county': 'Lake Pleasant, MA/Franklin County', 'city-state': 'Lake Pleasant, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b346'), 'city-state/county': 'Millers Falls, MA/Franklin County', 'city-state': 'Millers Falls, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b347'), 'city-state/county': 'Monroe Bridge, MA/Franklin County', 'city-state': 'Monroe Bridge, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b348'), 'city-state/county': 'Montague, MA/Franklin County', 'city-state': 'Montague, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b349'), 'city-state/county': 'Gill, MA/Franklin County', 'city-state': 'Gill, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b34a'), 'city-state/county': 'New Salem, MA/Franklin County', 'city-state': 'New Salem, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b34b'), 'city-state/county': 'Northfield, MA/Franklin County', 'city-state': 'Northfield, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b34c'), 'city-state/county': 'Orange, MA/Franklin County', 'city-state': 'Orange, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b34d'), 'city-state/county': 'Petersham, MA/Worcester County', 'city-state': 'Petersham, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b34e'), 'city-state/county': 'Rowe, MA/Franklin County', 'city-state': 'Rowe, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b34f'), 'city-state/county': 'Royalston, MA/Worcester County', 'city-state': 'Royalston, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b350'), 'city-state/county': 'Shelburne Falls, MA/Franklin County', 'city-state': 'Shelburne Falls, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b351'), 'city-state/county': 'South Deerfield, MA/Franklin County', 'city-state': 'South Deerfield, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b352'), 'city-state/county': 'Sunderland, MA/Franklin County', 'city-state': 'Sunderland, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b353'), 'city-state/county': 'Turners Falls, MA/Franklin County', 'city-state': 'Turners Falls, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b354'), 'city-state/county': 'Warwick, MA/Franklin County', 'city-state': 'Warwick, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b355'), 'city-state/county': 'Wendell, MA/Franklin County', 'city-state': 'Wendell, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b356'), 'city-state/county': 'Wendell Depot, MA/Franklin County', 'city-state': 'Wendell Depot, MA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b357'), 'city-state/county': 'Fitchburg, MA/Worcester County', 'city-state': 'Fitchburg, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b358'), 'city-state/county': 'Ashburnham, MA/Worcester County', 'city-state': 'Ashburnham, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b359'), 'city-state/county': 'Ashby, MA/Middlesex County', 'city-state': 'Ashby, MA', 'county': 'Middlesex County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b35a'), 'city-state/county': 'Ayer, MA/Middlesex County', 'city-state': 'Ayer, MA', 'county': 'Middlesex County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b35b'), 'city-state/county': 'Devens, MA/Worcester County', 'city-state': 'Devens, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b35c'), 'city-state/county': 'Baldwinville, MA/Worcester County', 'city-state': 'Baldwinville, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b35d'), 'city-state/county': 'East Templeton, MA/Worcester County', 'city-state': 'East Templeton, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b35e'), 'city-state/county': 'Gardner, MA/Worcester County', 'city-state': 'Gardner, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b35f'), 'city-state/county': 'Westminster, MA/Worcester County', 'city-state': 'Westminster, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b360'), 'city-state/county': 'Groton, MA/Middlesex County', 'city-state': 'Groton, MA', 'county': 'Middlesex County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b361'), 'city-state/county': 'Harvard, MA/Worcester County', 'city-state': 'Harvard, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b362'), 'city-state/county': 'Hubbardston, MA/Worcester County', 'city-state': 'Hubbardston, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b363'), 'city-state/county': 'Leominster, MA/Worcester County', 'city-state': 'Leominster, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b364'), 'city-state/county': 'Littleton, MA/Middlesex County', 'city-state': 'Littleton, MA', 'county': 'Middlesex County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b365'), 'city-state/county': 'Lunenburg, MA/Worcester County', 'city-state': 'Lunenburg, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b366'), 'city-state/county': 'Pepperell, MA/Middlesex County', 'city-state': 'Pepperell, MA', 'county': 'Middlesex County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b367'), 'city-state/county': 'Shirley, MA/Middlesex County', 'city-state': 'Shirley, MA', 'county': 'Middlesex County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b368'), 'city-state/county': 'Still River, MA/Worcester County', 'city-state': 'Still River, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b369'), 'city-state/county': 'Templeton, MA/Worcester County', 'city-state': 'Templeton, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b36a'), 'city-state/county': 'Townsend, MA/Middlesex County', 'city-state': 'Townsend, MA', 'county': 'Middlesex County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b36b'), 'city-state/county': 'West Groton, MA/Middlesex County', 'city-state': 'West Groton, MA', 'county': 'Middlesex County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b36c'), 'city-state/county': 'West Townsend, MA/Middlesex County', 'city-state': 'West Townsend, MA', 'county': 'Middlesex County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b36d'), 'city-state/county': 'Winchendon, MA/Worcester County', 'city-state': 'Winchendon, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b36e'), 'city-state/county': 'Winchendon Springs, MA/Worcester County', 'city-state': 'Winchendon Springs, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b36f'), 'city-state/county': 'Auburn, MA/Worcester County', 'city-state': 'Auburn, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b370'), 'city-state/county': 'Berlin, MA/Worcester County', 'city-state': 'Berlin, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b371'), 'city-state/county': 'Blackstone, MA/Worcester County', 'city-state': 'Blackstone, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b372'), 'city-state/county': 'Boylston, MA/Worcester County', 'city-state': 'Boylston, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b373'), 'city-state/county': 'Brookfield, MA/Worcester County', 'city-state': 'Brookfield, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b374'), 'city-state/county': 'Charlton, MA/Worcester County', 'city-state': 'Charlton, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b375'), 'city-state/county': 'Charlton City, MA/Worcester County', 'city-state': 'Charlton City, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b376'), 'city-state/county': 'Charlton Depot, MA/Worcester County', 'city-state': 'Charlton Depot, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b377'), 'city-state/county': 'Clinton, MA/Worcester County', 'city-state': 'Clinton, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b378'), 'city-state/county': 'East Brookfield, MA/Worcester County', 'city-state': 'East Brookfield, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b379'), 'city-state/county': 'Douglas, MA/Worcester County', 'city-state': 'Douglas, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b37a'), 'city-state/county': 'East Princeton, MA/Worcester County', 'city-state': 'East Princeton, MA', 'county': 'Worcester County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07ac9b37b'), 'city-state/county': 'Fiskdale, MA/Worcester County', 'city-state': 'Fiskdale, MA', 'county': 'Worcester County'}
# ...
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50ca'), 'city-state/county': 'Joint Base Lewis Mcchord, Lewis Mcchord, Mcchord Afb, Tacoma, WA/Pierce County', 'city-state': 'Joint Base Lewis Mcchord, Lewis Mcchord, Mcchord Afb, Tacoma, WA', 'county': 'Pierce County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50cb'), 'city-state/county': 'Parkland, WA/Pierce County', 'city-state': 'Parkland, WA', 'county': 'Pierce County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50cc'), 'city-state/county': 'University Pl, University Place, WA/Pierce County', 'city-state': 'University Pl, University Place, WA', 'county': 'Pierce County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50cd'), 'city-state/county': 'Fircrest, University Pl, University Place, WA/Pierce County', 'city-state': 'Fircrest, University Pl, University Place, WA', 'county': 'Pierce County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50ce'), 'city-state/county': 'Tacoma, University Pl, WA/Pierce County', 'city-state': 'Tacoma, University Pl, WA', 'county': 'Pierce County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50cf'), 'city-state/county': 'Oakbrook, Tacoma, WA/Pierce County', 'city-state': 'Oakbrook, Tacoma, WA', 'county': 'Pierce County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50d0'), 'city-state/county': 'Copalis Xing, WA/Grays Harbor County', 'city-state': 'Copalis Xing, WA', 'county': 'Grays Harbor County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50d1'), 'city-state/county': 'Ocean City, WA/Grays Harbor County', 'city-state': 'Ocean City, WA', 'county': 'Grays Harbor County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50d2'), 'city-state/county': 'Skok, Skokomish Nation, WA/Mason County', 'city-state': 'Skok, Skokomish Nation, WA', 'county': 'Mason County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50d3'), 'city-state/county': 'Cook, WA/Klickitat County', 'city-state': 'Cook, WA', 'county': 'Klickitat County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50d4'), 'city-state/county': 'N Bonneville, WA/Skamania County', 'city-state': 'N Bonneville, WA', 'county': 'Skamania County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50d5'), 'city-state/county': 'E Wenatchee, Wenatchee, WA/Douglas County', 'city-state': 'E Wenatchee, Wenatchee, WA', 'county': 'Douglas County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50d6'), 'city-state/county': 'Union Gap, WA/Yakima County', 'city-state': 'Union Gap, WA', 'county': 'Yakima County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50d7'), 'city-state/county': 'Gleed, WA/Yakima County', 'city-state': 'Gleed, WA', 'county': 'Yakima County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50d8'), 'city-state/county': 'Goose Prairie, WA/Yakima County', 'city-state': 'Goose Prairie, WA', 'county': 'Yakima County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50d9'), 'city-state/county': 'S Cle Elum, WA/Kittitas County', 'city-state': 'S Cle Elum, WA', 'county': 'Kittitas County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50da'), 'city-state/county': 'Airway Hgts, WA/Spokane County', 'city-state': 'Airway Hgts, WA', 'county': 'Spokane County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50db'), 'city-state/county': 'Fairchild Afb, WA/Spokane County', 'city-state': 'Fairchild Afb, WA', 'county': 'Spokane County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50dc'), 'city-state/county': 'Liberty Lake, Spokane Valley, Spokane Vly, WA/Spokane County', 'city-state': 'Liberty Lake, Spokane Valley, Spokane Vly, WA', 'county': 'Spokane County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50dd'), 'city-state/county': 'Sprague, WA/Whitman County', 'city-state': 'Sprague, WA', 'county': 'Whitman County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50de'), 'city-state/county': 'Espanola, WA/Spokane County', 'city-state': 'Espanola, WA', 'county': 'Spokane County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50df'), 'city-state/county': 'Nine Mile Fls, WA/Stevens County', 'city-state': 'Nine Mile Fls, WA', 'county': 'Stevens County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50e0'), 'city-state/county': 'City Of Spokane Valley, Spokane Valley, Spokane Vly, WA/Spokane County', 'city-state': 'City Of Spokane Valley, Spokane Valley, Spokane Vly, WA', 'county': 'Spokane County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50e1'), 'city-state/county': 'City Of Spokane Valley, Spokane Valley, Spokane Vly, WA/Spokane County', 'city-state': 'City Of Spokane Valley, Spokane Valley, Spokane Vly, WA', 'county': 'Spokane County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50e2'), 'city-state/county': 'Kettle Falls, WA/Ferry County', 'city-state': 'Kettle Falls, WA', 'county': 'Ferry County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50e3'), 'city-state/county': 'Kettle Falls, WA/Ferry County', 'city-state': 'Kettle Falls, WA', 'county': 'Ferry County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50e4'), 'city-state/county': 'Diamond, WA/Whitman County', 'city-state': 'Diamond, WA', 'county': 'Whitman County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50e5'), 'city-state/county': 'Deer Meadows, Seven Bays, WA/Lincoln County', 'city-state': 'Deer Meadows, Seven Bays, WA', 'county': 'Lincoln County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50e6'), 'city-state/county': 'Metaline Fls, WA/Pend Oreille County', 'city-state': 'Metaline Fls, WA', 'county': 'Pend Oreille County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50e7'), 'city-state/county': 'Plaza, WA/Whitman County', 'city-state': 'Plaza, WA', 'county': 'Whitman County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50e8'), 'city-state/county': 'Spokane Valley, Spokane Vly, WA/Spokane County', 'city-state': 'Spokane Valley, Spokane Vly, WA', 'county': 'Spokane County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50e9'), 'city-state/county': 'Millwood, Spokane Valley, Spokane Vly, WA/Spokane County', 'city-state': 'Millwood, Spokane Valley, Spokane Vly, WA', 'county': 'Spokane County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50ea'), 'city-state/county': 'Sunset Hill, WA/Spokane County', 'city-state': 'Sunset Hill, WA', 'county': 'Spokane County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50eb'), 'city-state/county': 'Tri Cities, WA/Franklin County', 'city-state': 'Tri Cities, WA', 'county': 'Franklin County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50ec'), 'city-state/county': 'Hatton, WA/Adams County', 'city-state': 'Hatton, WA', 'county': 'Adams County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50ed'), 'city-state/county': 'Desert Aire, WA/Grant County', 'city-state': 'Desert Aire, WA', 'county': 'Grant County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50ee'), 'city-state/county': 'Lowden, WA/Walla Walla County', 'city-state': 'Lowden, WA', 'county': 'Walla Walla County'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50ef'), 'city-state/county': 'Anchorage, Fort Richardson, Ft Richardson, AK/Anchorage Municipality', 'city-state': 'Anchorage, Fort Richardson, Ft Richardson, AK', 'county': 'Anchorage Municipality'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50f0'), 'city-state/county': 'Anchorage, Elmendorf Afb, AK/Anchorage Municipality', 'city-state': 'Anchorage, Elmendorf Afb, AK', 'county': 'Anchorage Municipality'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50f1'), 'city-state/county': 'King Salmon, AK/Lake and Peninsula Borough', 'city-state': 'King Salmon, AK', 'county': 'Lake and Peninsula Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50f2'), 'city-state/county': 'Nikolaevsk, AK/Kenai Peninsula Borough', 'city-state': 'Nikolaevsk, AK', 'county': 'Kenai Peninsula Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50f3'), 'city-state/county': 'Chuathbaluk, Stony River, AK/Bethel Census Area', 'city-state': 'Chuathbaluk, Stony River, AK', 'county': 'Bethel Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50f4'), 'city-state/county': 'Atmautluak, Napaskiak, Newtok, AK/Bethel Census Area', 'city-state': 'Atmautluak, Napaskiak, Newtok, AK', 'county': 'Bethel Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50f5'), 'city-state/county': 'Chignik Lagn, AK/Lake and Peninsula Borough', 'city-state': 'Chignik Lagn, AK', 'county': 'Lake and Peninsula Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50f6'), 'city-state/county': 'Adak, Nelson Lagoon, AK/Aleutians East Borough', 'city-state': 'Adak, Nelson Lagoon, AK', 'county': 'Aleutians East Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50f7'), 'city-state/county': 'Cooper Lndg, AK/Kenai Peninsula Borough', 'city-state': 'Cooper Lndg, AK', 'county': 'Kenai Peninsula Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50f8'), 'city-state/county': 'Chenega Bay, AK/Valdez-Cordova Census Area', 'city-state': 'Chenega Bay, AK', 'county': 'Valdez-Cordova Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50f9'), 'city-state/county': 'Koliganek, Twin Hills, AK/Dillingham Census Area', 'city-state': 'Koliganek, Twin Hills, AK', 'county': 'Dillingham Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50fa'), 'city-state/county': 'Miers Lake, Slana, AK/Valdez-Cordova Census Area', 'city-state': 'Miers Lake, Slana, AK', 'county': 'Valdez-Cordova Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50fb'), 'city-state/county': 'Saint Paul Island, St George Is, St Paul Isle, AK/Aleutians West Census Area', 'city-state': 'Saint Paul Island, St George Is, St Paul Isle, AK', 'county': 'Aleutians West Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50fc'), 'city-state/county': 'English Bay, Fritz Creek, Halibut Cove, Kachemak, Nanwalek, Port Graham, AK/Kenai Peninsula Borough', 'city-state': 'English Bay, Fritz Creek, Halibut Cove, Kachemak, Nanwalek, Port Graham, AK', 'county': 'Kenai Peninsula Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50fd'), 'city-state/county': 'Kokhanok, AK/Lake and Peninsula Borough', 'city-state': 'Kokhanok, AK', 'county': 'Lake and Peninsula Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50fe'), 'city-state/county': 'Igiugig, AK/Bristol Bay Borough', 'city-state': 'Igiugig, AK', 'county': 'Bristol Bay Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca50ff'), 'city-state/county': 'Akhiok, Chiniak, AK/Kodiak Island Borough', 'city-state': 'Akhiok, Chiniak, AK', 'county': 'Kodiak Island Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5100'), 'city-state/county': 'Mountain Vlg, AK/Wade Hampton Census Area', 'city-state': 'Mountain Vlg, AK', 'county': 'Wade Hampton Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5101'), 'city-state/county': 'Russian Msn, AK/Wade Hampton Census Area', 'city-state': 'Russian Msn, AK', 'county': 'Wade Hampton Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5102'), 'city-state/county': 'Saint Paul, St Paul, St Paul Isle, AK/Aleutians West Census Area', 'city-state': 'Saint Paul, St Paul, St Paul Isle, AK', 'county': 'Aleutians West Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5103'), 'city-state/county': 'Chickaloon, AK/Matanuska-Susitna Borough', 'city-state': 'Chickaloon, AK', 'county': 'Matanuska-Susitna Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5104'), 'city-state/county': 'Girdwood, AK/Valdez-Cordova Census Area', 'city-state': 'Girdwood, AK', 'county': 'Valdez-Cordova Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5105'), 'city-state/county': 'Coldfoot, AK/Fairbanks North Star Borough', 'city-state': 'Coldfoot, AK', 'county': 'Fairbanks North Star Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5106'), 'city-state/county': 'Ft Wainwright, AK/Fairbanks North Star Borough', 'city-state': 'Ft Wainwright, AK', 'county': 'Fairbanks North Star Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5107'), 'city-state/county': 'Nenana, AK/Denali Borough', 'city-state': 'Nenana, AK', 'county': 'Denali Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5108'), 'city-state/county': 'Nenana, AK/Denali Borough', 'city-state': 'Nenana, AK', 'county': 'Denali Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5109'), 'city-state/county': 'Steese, AK/Fairbanks North Star Borough', 'city-state': 'Steese, AK', 'county': 'Fairbanks North Star Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca510a'), 'city-state/county': 'Badger, AK/Fairbanks North Star Borough', 'city-state': 'Badger, AK', 'county': 'Fairbanks North Star Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca510b'), 'city-state/county': 'Anaktuvuk, AK/North Slope Borough', 'city-state': 'Anaktuvuk, AK', 'county': 'North Slope Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca510c'), 'city-state/county': 'Arctic Vlg, AK/Yukon-Koyukuk Census Area', 'city-state': 'Arctic Vlg, AK', 'county': 'Yukon-Koyukuk Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca510d'), 'city-state/county': 'Delta Jct, Delta Junction, AK/Southeast Fairbanks Census Area', 'city-state': 'Delta Jct, Delta Junction, AK', 'county': 'Southeast Fairbanks Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca510e'), 'city-state/county': 'Delta Jct, Dot Lake, AK/Southeast Fairbanks Census Area', 'city-state': 'Delta Jct, Dot Lake, AK', 'county': 'Southeast Fairbanks Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca510f'), 'city-state/county': 'Denali Park, AK/Denali Borough', 'city-state': 'Denali Park, AK', 'county': 'Denali Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5110'), 'city-state/county': 'Manley Spgs, AK/Yukon-Koyukuk Census Area', 'city-state': 'Manley Spgs, AK', 'county': 'Yukon-Koyukuk Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5111'), 'city-state/county': 'Lk Minchumina, AK/Yukon-Koyukuk Census Area', 'city-state': 'Lk Minchumina, AK', 'county': 'Yukon-Koyukuk Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5112'), 'city-state/county': 'Diomede, Golovin, Little Diomede, Ltl Diomede, AK/Nome Census Area', 'city-state': 'Diomede, Golovin, Little Diomede, Ltl Diomede, AK', 'county': 'Nome Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5113'), 'city-state/county': 'Stevens Vlg, AK/Yukon-Koyukuk Census Area', 'city-state': 'Stevens Vlg, AK', 'county': 'Yukon-Koyukuk Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5114'), 'city-state/county': 'Mentasta Lake, AK/Southeast Fairbanks Census Area', 'city-state': 'Mentasta Lake, AK', 'county': 'Southeast Fairbanks Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5115'), 'city-state/county': 'White Mtn, AK/Nome Census Area', 'city-state': 'White Mtn, AK', 'county': 'Nome Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5116'), 'city-state/county': 'Brevig Msn, AK/Nome Census Area', 'city-state': 'Brevig Msn, AK', 'county': 'Nome Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5117'), 'city-state/county': 'Kupreanof, AK/Petersburg Census Area', 'city-state': 'Kupreanof, AK', 'county': 'Petersburg Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5118'), 'city-state/county': 'Prt Alexander, Sitka, AK/Petersburg Census Area', 'city-state': 'Prt Alexander, Sitka, AK', 'county': 'Petersburg Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca5119'), 'city-state/county': 'Tenakee Spgs, AK/Hoonah-Angoon Census Area', 'city-state': 'Tenakee Spgs, AK', 'county': 'Hoonah-Angoon Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca511a'), 'city-state/county': 'Edna Bay, Kasaan, Naukati Bay, Saxman, AK/Ketchikan Gateway Borough', 'city-state': 'Edna Bay, Kasaan, Naukati Bay, Saxman, AK', 'county': 'Ketchikan Gateway Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca511b'), 'city-state/county': 'Ketchikan, AK/Wrangell City and Borough', 'city-state': 'Ketchikan, AK', 'county': 'Wrangell City and Borough'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca511c'), 'city-state/county': 'Ketchikan, AK/Prince of Wales-Hyder Census Area', 'city-state': 'Ketchikan, AK', 'county': 'Prince of Wales-Hyder Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca511d'), 'city-state/county': 'Ketchikan, AK/Prince of Wales-Hyder Census Area', 'city-state': 'Ketchikan, AK', 'county': 'Prince of Wales-Hyder Census Area'}
# {'_id': ObjectId('5e1a1b6e591e2ce07aca511e'), 'city-state/county': 'Edna Bay, Kasaan, AK/Prince of Wales-Outer Ketchikan Borough', 'city-state': 'Edna Bay, Kasaan, AK', 'county': 'Prince of Wales-Outer Ketchikan Borough'}
